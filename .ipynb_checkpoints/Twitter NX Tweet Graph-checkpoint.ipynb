# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import tweepy
import os
import datetime, time
import re

# %%
home_dir = "/Users/christopherallison/.virtualenvs/py_twi/results"
save_dir = "/Users/christopherallison/Documents/Coding/Gephi/twitter"

# Enter your search queries here
search_queries = "rstats python".split()

# %% [markdown]
# ### Functions for data prep

# %%
# Convert text to camel_case

first_cap_re = re.compile('(.)([A-Z][a-z]+)')
all_cap_re = re.compile('([a-z0-9])([A-Z])')

def convert(name):
    s1 = first_cap_re.sub(r'\1_\2', name)
    return all_cap_re.sub(r'\1_\2', s1).lower()

# %%
# Remove empty mentions created through dataframe list comprehension
# i.e, ['twitter_user_A', None]

def clean_mentions(scr, men):
    temp = []
    for s, m in zip(scr, men):
        if m:
            for i, v in enumerate(m):
                temp.append([s, m[i]])
        else:
            pass
        
    return temp

# %%
# Remove edges for reply_to_tweet where no reply exists
# Need to add code to assign weight for duplicate edges - multiple mentions or replies to from same person
# Will return list on len 3 - node, target, weight

def clean_edges(edge_list):
    clean_edges = []

    for e in edge_list:
        if e[1] == None:
            pass
        else:
            clean_edges.append(e)
            
    return clean_edges

# %%
# Check for duplicates in edges and compute number of repeats as edge weight

def sort_and_weight(edges):
    temp = {}

    for i in edges:
        try:
            temp[str(i)]['weight'] += 1
        except KeyError:
            temp[str(i)] = {}
            temp[str(i)]['node'] = i[0]
            temp[str(i)]['target'] = i[1]
            temp[str(i)]['weight'] = 1

    return temp

# %%
def twitter_data_to_graph(search_query):
    
    for sq in search_query:
        
        fname = open(os.path.join(home_dir, 'search_{}.json'.format(sq)))
        
        # Load the JSON file
        df = pd.read_json(fname)
        
        # Swap rows & columns
        df2 = df.transpose()
        
        # Change index from Timestamp to integer
        df2.index = [t.value // 1 for t in df2.index]
        df2.head()
        
        # Pull hashtags from dict
        new_hash = []

        for h in df2.hashtags:
            n = []
            for i in h:
                n.append(i['text'].lower())
            new_hash.append(n)
            
        # Pull user names from dict
        new_mentions = []

        for m in df2.user_mentions:
            n = []
            for i in m:
                n.append(i['screen_name'])
            new_mentions.append(n)
            
        # Set up lists for node & edge creation
        texts = [text for text in df2.text]
        dates = [d for d in df2.date]
        replies = [r for r in df2.reply_to_tweet]
        user_replies = [u for u in df2.reply_to]
        mentions = [m for m in new_mentions]
        screen_names = [sn for sn in df2.user_screen_name]
        hashtags = [h for h in new_hash]
        retweets = [r for r in df2.retweet_count]
        id_str = [i for i in df2.id_str]
        quote_id_str = [q for q in df2.quoted_status_id_str]
        coords = [c for c in df2.coordinates]
        favorites = [f for f in df2.favorite_count]
        
        # Create one node for each tweet with embedded data - Graph N
        for i, n, d, h, r, t, q, c, f  in zip(id_str, screen_names, dates, hashtags, retweets, texts, quote_id_str, coords, favorites):
            N.add_node(i, attr_dict={
                    'name':n,
                    'date':d,
                    'hashtags':str(h),
                    'retweets':r,
                    'text':t, 
                    #'quoted_id':q,
                    #'coords':c,
                    #'favorites':f,
                })
        
        # Create edges list for each tweet & reply_to_tweet
        
        edges_r = [[n, r] for n,r in zip(id_str, replies)]
        edges_q = [[n, q] for n,q in zip(id_str, quote_id_str)]
        
        # Combine edges and prep - expanding multiple @-mentions FREX
        edges_all = edges_r + edges_q
        edges_all = clean_edges(edges_all)
        
        # Create edge weight as number of repeat replies & @-mentions
        
        edge_dict = sort_and_weight(edges_all)
        
        # Add edges for @mentions and replies to users
        for e in edge_dict:
            N.add_edge(edge_dict[e]['node'],
                       edge_dict[e]['target'],
                       weight=edge_dict[e]['weight'])
            
        # Insert Data analysis here
        print("Nodes: {}, Edges: {}".format(len(N.nodes()), len(N.edges())))
        
    # Write N graph in gexf for Gephi
    file_name = "{}_tweets_graph_{}.gexf".format(
        convert("_".join(search_queries)),
        datetime.datetime.now())
    
    nx.write_gexf(N, os.path.join(save_dir, file_name))

# %%
# Set up Graph
N = nx.DiGraph()

# %%
twitter_data_to_graph(search_queries)
# Out:
# Nodes: 1028, Edges: 35
# Nodes: 2027, Edges: 52

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-419c79c3c721> in <module>()
# ----> 1 df2.head()
#
# NameError: name 'df2' is not defined

# %%
# Out:
#                                     1990-01-09 01:51:10.291136512  \
# coordinates                                                  None
# date                                          2015-08-13 15:28:42
# entities        {'symbols': [], 'urls': [{'display_url': 'micr...
# favorite_count                                                  3
# hashtags        [{'text': 'python', 'indices': [30, 37]}, {'te...
#
#                                     1990-01-09 01:52:34.508730368  \
# coordinates                                                  None
# date                                          2015-08-13 15:29:03
# entities        {'symbols': [], 'urls': [], 'media': [{'indice...
# favorite_count                                                  0
# hashtags              [{'text': 'python', 'indices': [100, 107]}]
#
#                                     1990-01-09 01:58:04.805947393  \
# coordinates                                                  None
# date                                          2015-08-13 15:30:21
# entities        {'symbols': [], 'urls': [{'display_url': 'abiz...
# favorite_count                                                  0
# hashtags        [{'text': 'Python', 'indices': [0, 7]}, {'text...
#
#                                     1990-01-09 01:58:19.490238464  \
# coordinates                                                  None
# date                                          2015-08-13 15:30:25
# entities        {'symbols': [], 'urls': [{'display_url': 'pypi...
# favorite_count                                                  0
# hashtags        [{'text': 'Euchner', 'indices': [57, 65]}, {'t...
#
#                                     1990-01-09 01:58:32.035368960  \
# coordinates                                                  None
# date                                          2015-08-13 15:30:28
# entities        {'symbols': [], 'urls': [{'display_url': 'buff...
# favorite_count                                                  0
# hashtags        [{'text': 'python', 'indices': [90, 97]}, {'te...
#
#                                     1990-01-09 01:59:04.868261889  \
# coordinates                                                  None
# date                                          2015-08-13 15:30:36
# entities        {'symbols': [], 'urls': [{'display_url': 'bit....
# favorite_count                                                  0
# hashtags        [{'text': 'python', 'indices': [68, 75]}, {'te...
#
#                                     1990-01-09 01:59:16.494966784  \
# coordinates                                                  None
# date                                          2015-08-13 15:30:38
# entities        {'symbols': [], 'urls': [{'display_url': 'buff...
# favorite_count                                                  0
# hashtags        [{'text': 'programming', 'indices': [95, 107]}...
#
#                                     1990-01-09 01:59:37.286156288  \
# coordinates                                                  None
# date                                          2015-08-13 15:30:43
# entities        {'symbols': [], 'urls': [{'display_url': 'buff...
# favorite_count                                                  2
# hashtags        [{'text': 'webdev', 'indices': [35, 42]}, {'te...
#
#                                     1990-01-09 01:59:55.560714240  \
# coordinates                                                  None
# date                                          2015-08-13 15:30:48
# entities        {'symbols': [], 'urls': [{'display_url': 'neuv...
# favorite_count                                                  0
# hashtags        [{'text': 'Python', 'indices': [14, 21]}, {'te...
#
#                                     1990-01-09 02:01:07.341893632  \
# coordinates                                                  None
# date                                          2015-08-13 15:31:05
# entities        {'symbols': [], 'urls': [], 'hashtags': [{'tex...
# favorite_count                                                  0
# hashtags        [{'text': 'python', 'indices': [64, 71]}, {'te...
#
#                                       ...                          \
# coordinates                           ...
# date                                  ...
# entities                              ...
# favorite_count                        ...
# hashtags                              ...
#
#                                     1990-01-11 04:21:36.238456833  \
# coordinates                                                  None
# date                                          2015-08-14 03:31:13
# entities        {'symbols': [], 'urls': [{'display_url': 'stac...
# favorite_count                                                  0
# hashtags              [{'text': 'Python', 'indices': [104, 111]}]
#
#                                     1990-01-11 04:24:03.085381632  \
# coordinates     {'type': 'Point', 'coordinates': [-117.9533807...
# date                                          2015-08-14 03:31:48
# entities        {'symbols': [], 'urls': [{'display_url': 'inst...
# favorite_count                                                  0
# hashtags        [{'text': 'amazing', 'indices': [28, 36]}, {'t...
#
#                                     1990-01-11 04:25:32.205785088  \
# coordinates                                                  None
# date                                          2015-08-14 03:32:09
# entities        {'symbols': [], 'urls': [], 'hashtags': [{'tex...
# favorite_count                                                  0
# hashtags        [{'text': 'C', 'indices': [14, 16]}, {'text': ...
#
#                                     1990-01-11 04:30:20.459479042  \
# coordinates                                                  None
# date                                          2015-08-14 03:33:18
# entities        {'symbols': [], 'urls': [{'display_url': 'neuv...
# favorite_count                                                  1
# hashtags        [{'text': 'Programmatore', 'indices': [33, 47]...
#
#                                     1990-01-11 04:35:39.792666624  \
# coordinates                                                  None
# date                                          2015-08-14 03:34:34
# entities        {'symbols': [], 'urls': [{'display_url': 'daan...
# favorite_count                                                  0
# hashtags        [{'text': 'python', 'indices': [53, 60]}, {'te...
#
#                                     1990-01-11 04:37:35.236800512  \
# coordinates                                                  None
# date                                          2015-08-14 03:35:02
# entities        {'symbols': [], 'urls': [{'display_url': 'gith...
# favorite_count                                                  0
# hashtags                [{'text': 'python', 'indices': [92, 99]}]
#
#                                     1990-01-11 04:44:58.457325568  \
# coordinates                                                  None
# date                                          2015-08-14 03:36:47
# entities        {'symbols': [], 'urls': [{'display_url': 'daan...
# favorite_count                                                  0
# hashtags        [{'text': 'python', 'indices': [71, 78]}, {'te...
#
#                                     1990-01-11 04:48:40.050802689  \
# coordinates                                                  None
# date                                          2015-08-14 03:37:40
# entities        {'symbols': [], 'urls': [{'display_url': 'buff...
# favorite_count                                                  0
# hashtags        [{'text': 'Python', 'indices': [21, 28]}, {'te...
#
#                                     1990-01-11 05:10:47.904546816  \
# coordinates                                                  None
# date                                          2015-08-14 03:42:57
# entities        {'symbols': [], 'urls': [{'display_url': 'isaa...
# favorite_count                                                  0
# hashtags        [{'text': 'python', 'indices': [58, 65]}, {'te...
#
#                                     1990-01-11 05:12:22.838276096
# coordinates                                                  None
# date                                          2015-08-14 03:43:19
# entities        {'symbols': [], 'urls': [], 'hashtags': [{'tex...
# favorite_count                                                  0
# hashtags                [{'text': 'Python', 'indices': [23, 30]}]
#
# [5 rows x 1000 columns]

# %%
# Out:
#                               coordinates                 date  \
# 1990-01-09 01:51:10.291136512        None  2015-08-13 15:28:42
# 1990-01-09 01:52:34.508730368        None  2015-08-13 15:29:03
# 1990-01-09 01:58:04.805947393        None  2015-08-13 15:30:21
# 1990-01-09 01:58:19.490238464        None  2015-08-13 15:30:25
# 1990-01-09 01:58:32.035368960        None  2015-08-13 15:30:28
#
#                                                                         entities  \
# 1990-01-09 01:51:10.291136512  {'symbols': [], 'urls': [{'display_url': 'micr...
# 1990-01-09 01:52:34.508730368  {'symbols': [], 'urls': [], 'media': [{'indice...
# 1990-01-09 01:58:04.805947393  {'symbols': [], 'urls': [{'display_url': 'abiz...
# 1990-01-09 01:58:19.490238464  {'symbols': [], 'urls': [{'display_url': 'pypi...
# 1990-01-09 01:58:32.035368960  {'symbols': [], 'urls': [{'display_url': 'buff...
#
#                               favorite_count  \
# 1990-01-09 01:51:10.291136512              3
# 1990-01-09 01:52:34.508730368              0
# 1990-01-09 01:58:04.805947393              0
# 1990-01-09 01:58:19.490238464              0
# 1990-01-09 01:58:32.035368960              0
#
#                                                                         hashtags  \
# 1990-01-09 01:51:10.291136512  [{'text': 'python', 'indices': [30, 37]}, {'te...
# 1990-01-09 01:52:34.508730368        [{'text': 'python', 'indices': [100, 107]}]
# 1990-01-09 01:58:04.805947393  [{'text': 'Python', 'indices': [0, 7]}, {'text...
# 1990-01-09 01:58:19.490238464  [{'text': 'Euchner', 'indices': [57, 65]}, {'t...
# 1990-01-09 01:58:32.035368960  [{'text': 'python', 'indices': [90, 97]}, {'te...
#
#                                            id_str lang quoted_status reply_to  \
# 1990-01-09 01:51:10.291136512  631849870291136512   en         False     None
# 1990-01-09 01:52:34.508730368  631849954508730368   en         False     None
# 1990-01-09 01:58:04.805947393  631850284805947393   en         False     None
# 1990-01-09 01:58:19.490238464  631850299490238464   de         False     None
# 1990-01-09 01:58:32.035368960  631850312035368960   de         False     None
#
#                               reply_to_tweet retweet_count  \
# 1990-01-09 01:51:10.291136512           None             0
# 1990-01-09 01:52:34.508730368           None            14
# 1990-01-09 01:58:04.805947393           None             0
# 1990-01-09 01:58:19.490238464           None             1
# 1990-01-09 01:58:32.035368960           None             0
#
#                                                                             text  \
# 1990-01-09 01:51:10.291136512  Microsoft teaching how to use #python and #Dja...
# 1990-01-09 01:52:34.508730368  RT @MuseumsInspire: Moving robots in the 'Pi P...
# 1990-01-09 01:58:04.805947393  #Python-gdal create geotiff from array with co...
# 1990-01-09 01:58:19.490238464  RT @dajool_com: Hat jemand ein Electronic-Key-...
# 1990-01-09 01:58:32.035368960  Python Library for Amadeus Travel Innovation S...
#
#                                                                             urls  \
# 1990-01-09 01:51:10.291136512  [{'display_url': 'microsoftvirtualacademy.com/...
# 1990-01-09 01:52:34.508730368                                                 []
# 1990-01-09 01:58:04.805947393  [{'display_url': 'abizy.com/p/view.html?ur…', ...
# 1990-01-09 01:58:19.490238464  [{'display_url': 'pypi.python.org/pypi/eks/0.1...
# 1990-01-09 01:58:32.035368960  [{'display_url': 'buff.ly/1P8q30m', 'indices':...
#
#                                                                             user  \
# 1990-01-09 01:51:10.291136512  {'contributors_enabled': False, 'notifications...
# 1990-01-09 01:52:34.508730368  {'contributors_enabled': False, 'notifications...
# 1990-01-09 01:58:04.805947393  {'contributors_enabled': False, 'notifications...
# 1990-01-09 01:58:19.490238464  {'contributors_enabled': False, 'notifications...
# 1990-01-09 01:58:32.035368960  {'contributors_enabled': False, 'notifications...
#
#                                                                    user_mentions  \
# 1990-01-09 01:51:10.291136512                                                 []
# 1990-01-09 01:52:34.508730368  [{'indices': [3, 18], 'id': 3195219910, 'scree...
# 1990-01-09 01:58:04.805947393                                                 []
# 1990-01-09 01:58:19.490238464  [{'indices': [3, 14], 'id': 119441666, 'screen...
# 1990-01-09 01:58:32.035368960                                                 []
#
#                               user_screen_name
# 1990-01-09 01:51:10.291136512  pollitosabroson
# 1990-01-09 01:52:34.508730368         ryanteck
# 1990-01-09 01:58:04.805947393     Naijaknowhow
# 1990-01-09 01:58:19.490238464             lgtr
# 1990-01-09 01:58:32.035368960      PyBaltimore

# %% [markdown]
# Just noticed that date are incorrect - these are the tweet ID's that have been converted by accident

# %% [markdown]
# ## Scripts for setting up graph of all tweets

# %%
# Out:
# [('631734304524005376',
#   {'date': '2015-08-13 07:49:29',
#    'hashtags': "['Python', 'optimization', 'performance', 'funny', 'Twitter']",
#    'name': 'slacknux',
#    'retweets': 0,
#    'text': 'Good talk https://t.co/iSZ7GS3BxH #Python #optimization #performance #funny #Twitter'}),
#  ('631565819781218304',
#   {'date': '2015-08-12 20:40:00',
#    'hashtags': "['Python', 'edtech']",
#    'name': 'Fuliski',
#    'retweets': 3,
#    'text': 'RT @Don_Watkins: Using #Python &amp; Raspberry Pi to communicate w/ Lego Mindstorms EV3 | https://t.co/v5LfotVS2o #edtech @rickweinberg @philsh…'}),
#  ('631569161991376896',
#   {'date': '2015-08-12 20:53:16',
#    'hashtags': "['IPython', 'Python']",
#    'name': 'ppblt',
#    'retweets': 24,
#    'text': 'RT @randal_olson: Big changes w/ the latest #IPython 4.0 release.\n\n"ipython notebook" no longer works?\n\nhttp://t.co/j0MAe0w7fy #Python http…'}),
#  ('631567373972058112',
#   {'date': '2015-08-12 20:46:10',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python dossier.store 0.4.2.dev1: Feature collection storage for DossierStack http://t.co/ghSv87J3zM'}),
#  ('631746113998036992',
#   {'date': '2015-08-13 08:36:25',
#    'hashtags': "['jobseeker', 'Python', 'Django', 'NorthCarolina', 'TheRTP']",
#    'name': 'NCLoverUSA',
#    'retweets': 1,
#    'text': 'RT @4PythonUsers: #jobseeker  13 Yrs #Python 8Yrs #Django #NorthCarolina #TheRTP Free http://t.co/lEYVaGcJU7'}),
#  ('631572088470564864',
#   {'date': '2015-08-12 21:04:54',
#    'hashtags': "['MongoDB', 'python']",
#    'name': 'emschuch',
#    'retweets': 1,
#    'text': 'today at school: practicing #MongoDB + #python with a very serious dataset.  @thisismetis http://t.co/hTKYDjsMdE'}),
#  ('631559010181869568',
#   {'date': '2015-08-12 20:12:56',
#    'hashtags': "['nodejs', 'php', 'ruby', 'python', 'swift', 'java', 'mongodb', 'ang']",
#    'name': 'ameanmbot',
#    'retweets': 3,
#    'text': 'RT @StackMean: RT crystalcodegen: Why REST at API when Crystal does it all? http://t.co/C1z1seWF4G #nodejs #php #ruby #python #swift #java …'}),
#  ('631565019403145216',
#   {'date': '2015-08-12 20:36:49',
#    'hashtags': "['php', 'developer', 'python', 'vacature', 'amsterdam']",
#    'name': 'TodoCoders',
#    'retweets': 0,
#    'text': 'PHP Developer  #php #developer #python #vacature  #amsterdam - Amsterdam, Noord-Holland http://t.co/TIEjDz0RC0'}),
#  ('631763559102283776',
#   {'date': '2015-08-13 09:45:44',
#    'hashtags': "['python', 'Python']",
#    'name': 'pythonews',
#    'retweets': 1,
#    'text': 'あまり知られていないCSSの12の事実(続編): 1年以上前に、私は最初の12 Little-known CSS Facts（あまり知られていないCSSの12の事実）を発表しました。Sit... http://t.co/DXvMJDsUaf #python #Python'}),
#  ('631572490414858241',
#   {'date': '2015-08-12 21:06:30',
#    'hashtags': "['Python', 'Developer', 'jobs']",
#    'name': 'TodoCoders',
#    'retweets': 0,
#    'text': 'Looking for a #Python #Developer - Marketing B2C SaaS #jobs http://t.co/c5BnezHdIC http://t.co/25BlKA6VdK'}),
#  ('631563947070619648',
#   {'date': '2015-08-12 20:32:33',
#    'hashtags': "['Python', 'edtech']",
#    'name': 'Workshopshed',
#    'retweets': 3,
#    'text': 'RT @Don_Watkins: Using #Python &amp; Raspberry Pi to communicate w/ Lego Mindstorms EV3 | https://t.co/v5LfotVS2o #edtech @rickweinberg @philsh…'}),
#  ('631776009113747457',
#   {'date': '2015-08-13 10:35:13',
#    'hashtags': "['Python', 'jobs']",
#    'name': 'coding_jobfeeds',
#    'retweets': 0,
#    'text': '#Python #jobs Data Scientist Engineer http://t.co/KdE4IXtuCY'}),
#  ('631561878171439104',
#   {'date': '2015-08-12 20:24:20',
#    'hashtags': "['python', 'science', 'web']",
#    'name': 'HCanS',
#    'retweets': 0,
#    'text': 'I love #python for #science and #web-apps. After 2 days dealing with a bug caused by an integers division (must use double). Moving to v3.5'}),
#  ('631758926409822208',
#   {'date': '2015-08-13 09:27:20',
#    'hashtags': "['MachineLearning', 'Pandas', 'DataScience', 'Python', 'ML']",
#    'name': 'py_coding',
#    'retweets': 5,
#    'text': "RT @marcel_dmg: Sklearn-pandas: a bridge between Scikit-Learn's #MachineLearning methods and #Pandas.\nhttps://t.co/n3wVSg6FB2\n#DataScience …"}),
#  ('631614756152078337',
#   {'date': '2015-08-12 23:54:27',
#    'hashtags': "['js', 'Python']",
#    'name': 'p2pWebMobileIt',
#    'retweets': 0,
#    'text': 'Software Test Engineer Python/JavaScript w/ #js #Python skills United Kingdom @p2people https://t.co/lH5FCJFgXO'}),
#  ('631753888820011008',
#   {'date': '2015-08-13 09:07:19',
#    'hashtags': "['python', 'webserver']",
#    'name': 'MammadGoli',
#    'retweets': 9,
#    'text': 'RT @pycoders: Let’s Build A Web Server. Part\xa03. http://t.co/h9ImZdPw6g #python #webserver'}),
#  ('631671722593288192',
#   {'date': '2015-08-13 03:40:49',
#    'hashtags': "['Python', 'geophysics']",
#    'name': 'mikegrimshaw2',
#    'retweets': 13,
#    'text': 'RT @kwinkunks: Introducing Bruges, a bag of really useful geophysical equations &amp; such... http://t.co/jb48WgPjFx #Python #geophysics http:/…'}),
#  ('631768592321671168',
#   {'date': '2015-08-13 10:05:44',
#    'hashtags': "['Python', 'Azure']",
#    'name': 'HarriSrivastav',
#    'retweets': 26,
#    'text': "RT @VisualStudio: ...so you're having trouble debugging a #Python Web app in #Azure Web Apps? This may help: http://t.co/4CTIuRwpfL http://…"}),
#  ('631583098308661248',
#   {'date': '2015-08-12 21:48:39',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python setuptools_scm 1.7.0: the blessed package to manage your versions by scm tags http://t.co/wuxP4cmaWW'}),
#  ('631686773073121280',
#   {'date': '2015-08-13 04:40:37',
#    'hashtags': "['Python']",
#    'name': 'JvCode',
#    'retweets': 1,
#    'text': 'RT @Python_Quest: Interactive slider to vary slice used in Bokeh image plot http://t.co/734y0DgT5n http://t.co/XxfGjinpVW #Python via @dv_g…'}),
#  ('631575038022434817',
#   {'date': '2015-08-12 21:16:37',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python pipsi 0.9: Wraps pip and virtualenv to install scripts http://t.co/rOAFzaU7w8'}),
#  ('631759658361991168',
#   {'date': '2015-08-13 09:30:14',
#    'hashtags': "['Python', 'jobs']",
#    'name': 'coding_jobfeeds',
#    'retweets': 0,
#    'text': '#Python #jobs McKinsey Digital Labs - Software Architect http://t.co/3Cmz85xV33 London'}),
#  ('631619599604301826',
#   {'date': '2015-08-13 00:13:42',
#    'hashtags': "['GlueViz', 'PyThon']",
#    'name': 'taufikedys',
#    'retweets': 0,
#    'text': '#GlueViz untuk #PyThon 3.4 akhirnya keluar .... ^_^\nhttp://t.co/VIbEcgtMGT http://t.co/QO2vLBg1o6'}),
#  ('631783627404275714',
#   {'date': '2015-08-13 11:05:29',
#    'hashtags': "['python']",
#    'name': 'richardasaurus',
#    'retweets': 0,
#    'text': 'Join us for "Finding more bugs with less work!" this evening at @onefinestay  http://t.co/DYBKyDtxPB #python'}),
#  ('631760905563447296',
#   {'date': '2015-08-13 09:35:12',
#    'hashtags': "['Python', 'jobs']",
#    'name': 'coding_jobfeeds',
#    'retweets': 0,
#    'text': '#Python #jobs Software Engineering Intern http://t.co/DH43o1IDux Oxford'}),
#  ('631573206495797248',
#   {'date': '2015-08-12 21:09:21',
#    'hashtags': "['Berlin', 'python', 'webdev']",
#    'name': 'jonDevBot',
#    'retweets': 10,
#    'text': 'RT @AbletonDev: We are sponsoring the next @djangogirls workshop in #Berlin. Save your spot dear @djangogirlsblin! https://t.co/gI77KcxfQC …'}),
#  ('631777240951455744',
#   {'date': '2015-08-13 10:40:06',
#    'hashtags': "['C', 'Python', 'Berlin']",
#    'name': 'CodingBerlin',
#    'retweets': 0,
#    'text': '#C++ and #Python @ HERE, a Nokia company (http://t.co/Uf2AgE5yul) #Berlin'}),
#  ('631631317604560896',
#   {'date': '2015-08-13 01:00:15',
#    'hashtags': "['video', 'ruby', 'python', 'java']",
#    'name': 'lobsters',
#    'retweets': 1,
#    'text': 'JVMLS 2015 - Multi-Language Runtime\nhttp://t.co/xSRXeUZqkU\nhttps://t.co/lEti5rfHkp #video #ruby #python #java'}),
#  ('631605216580796416',
#   {'date': '2015-08-12 23:16:32',
#    'hashtags': "['science', 'princess', 'Python']",
#    'name': 'DrRebeccaJ',
#    'retweets': 1,
#    'text': "Legendary NSW chief scientist Professor Mary O'Kane inspiring us about #science w #princess the #Python @AMscifest http://t.co/WcZP2v2Ub0"}),
#  ('631577174542274560',
#   {'date': '2015-08-12 21:25:07',
#    'hashtags': "['Python', 'jobs']",
#    'name': 'coding_jobfeeds',
#    'retweets': 0,
#    'text': '#Python #jobs Application Developer http://t.co/SbmbDE1SqK'}),
#  ('631764441646804992',
#   {'date': '2015-08-13 09:49:15',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python b2g_util 0.0.5: B2G Utilities http://t.co/fIkc7EZzKr'}),
#  ('631563070813417472',
#   {'date': '2015-08-12 20:29:04',
#    'hashtags': "['Flask', 'rethinkdb', 'Python']",
#    'name': 'JvCode',
#    'retweets': 1,
#    'text': '@RealPython Wrote a great post on @rethinkdb and #Flask. A great way to start error handling w/#rethinkdb. #Python'}),
#  ('631747970464022528',
#   {'date': '2015-08-13 08:43:48',
#    'hashtags': "['python', 'soundtrack', 'game', 'raspberrypi']",
#    'name': 'asbradbury',
#    'retweets': 4,
#    'text': 'RT @ProjectPyland: A quick look at the fantastic work done by @alexandaday on our soundtrack! https://t.co/Bh0lAPRnIH #python #soundtrack #…'}),
#  ('631573701616644097',
#   {'date': '2015-08-12 21:11:19',
#    'hashtags': "['python', 'java', 'python', 'java']",
#    'name': 'mpirnat',
#    'retweets': 4,
#    'text': 'RT @izcoder: Why #python better than #java? b/c when you have wrong base64 padding #python tells you about it. #java just writes random stu…'}),
#  ('631581793171427328',
#   {'date': '2015-08-12 21:43:28',
#    'hashtags': "['python']",
#    'name': 'dabeaz',
#    'retweets': 25,
#    'text': 'RT @ramalhoorg: Not news, but worth spreading: CPython is *way* above average in code quality http://t.co/5AaMdqLczE #python @Coverity @The…'}),
#  ('631677015104618496',
#   {'date': '2015-08-13 04:01:51',
#    'hashtags': "['deeplearning', 'python']",
#    'name': 'aidotech',
#    'retweets': 0,
#    'text': 'Faster deep learning with GPUs and Theano http://t.co/QR54NTTl8F  #deeplearning #python'}),
#  ('631775112698552320',
#   {'date': '2015-08-13 10:31:39',
#    'hashtags': "['javascript', 'python', 'jobs', 'hiring', 'careers']",
#    'name': 'findmjob',
#    'retweets': 0,
#    'text': 'Principal Test Analyst http://t.co/shXqj9BRke #javascript #python #jobs #hiring #careers'}),
#  ('631729669348311040',
#   {'date': '2015-08-13 07:31:04',
#    'hashtags': "['Python', 'IBMi']",
#    'name': 'panseybard',
#    'retweets': 1,
#    'text': 'RT @Proximity_ltd: Get rolling with #Python on #IBMi http://t.co/xxOLGzLrUu via @aaronbartell in @IBMimag'}),
#  ('631577237939187712',
#   {'date': '2015-08-12 21:25:22',
#    'hashtags': "['python']",
#    'name': 'adamtsang',
#    'retweets': 0,
#    'text': "I'm a Django type of guy #python"}),
#  ('631574627186307072',
#   {'date': '2015-08-12 21:14:59',
#    'hashtags': "['Python', 'Azure']",
#    'name': 'Sergio__Cabrera',
#    'retweets': 0,
#    'text': '"...so you\'re having trouble debugging a #Python Web app in #Azure Web Apps? This may help: … http://t.co/FGUjS55kt6"'}),
#  ('631734469406388224',
#   {'date': '2015-08-13 07:50:09',
#    'hashtags': "['Rproject', 'Python', 'SQL', 'Spark', 'Java', 'JavaScript', 'coding']",
#    'name': 'retweetjava',
#    'retweets': 3,
#    'text': 'RT @BestSQL: To code or not to code: #Rproject #Python visual #SQL #Spark #Java #JavaScript in KNIME https://t.co/YB4vKiSjVu #coding via @k…'}),
#  ('631599695773716480',
#   {'date': '2015-08-12 22:54:36',
#    'hashtags': "['Python', 'Quantitative', 'jobs']",
#    'name': 'NeuvooAdmBos',
#    'retweets': 0,
#    'text': 'Looking for a #Python #Quantitative Developer – Front Office Market Making Desk #jobs http://t.co/s6NFetsily'}),
#  ('631583454044405760',
#   {'date': '2015-08-12 21:50:04',
#    'hashtags': "['RaspberryPi', 'GameDev', 'Python', 'Linux', 'Cheap']",
#    'name': 'CowboyGamedevBt',
#    'retweets': 4,
#    'text': 'RT @Bensonix: What is a #RaspberryPi computer?\nhttp://t.co/NsxL4bWLPg\n#GameDev\n#Python\n#Linux\n#Cheap http://t.co/Div28mCJUb'}),
#  ('631638505664344064',
#   {'date': '2015-08-13 01:28:49',
#    'hashtags': "['Python', 'Azure']",
#    'name': 'ashishbasran',
#    'retweets': 26,
#    'text': "RT @VisualStudio: ...so you're having trouble debugging a #Python Web app in #Azure Web Apps? This may help: http://t.co/4CTIuRwpfL http://…"}),
#  ('631709673612120064',
#   {'date': '2015-08-13 06:11:37',
#    'hashtags': "['Python', 'DevOps', 'itpro', 'sysadmin', 'win10', 'vs2015']",
#    'name': 'PythonDaily',
#    'retweets': 8,
#    'text': 'RT @pcgeek86: Check out my overview of #Python Tools for @VisualStudio! Try it yourself! #DevOps #itpro #sysadmin #win10 #vs2015 http://t.c…'}),
#  ('631733453671657472',
#   {'date': '2015-08-13 07:46:07',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python pysentosa 0.1.19: Pysentosa - Python API for sentosa trading system http://t.co/2JYJAka09J'}),
#  ('631583229661851649',
#   {'date': '2015-08-12 21:49:10',
#    'hashtags': "['RaspberryPi', 'GameDev', 'Python', 'Linux', 'Cheap']",
#    'name': 'Bensonix',
#    'retweets': 4,
#    'text': 'What is a #RaspberryPi computer?\nhttp://t.co/NsxL4bWLPg\n#GameDev\n#Python\n#Linux\n#Cheap http://t.co/Div28mCJUb'}),
#  ('631766243998072832',
#   {'date': '2015-08-13 09:56:24',
#    'hashtags': "['Scientificcomputing', 'python']",
#    'name': 'hainm_comp',
#    'retweets': 0,
#    'text': '#Scientificcomputing #python http://t.co/v4SUgru2w7'}),
#  ('631718937990836224',
#   {'date': '2015-08-13 06:48:26',
#    'hashtags': "['nodejs', 'python']",
#    'name': 'irfnhmd',
#    'retweets': 1,
#    'text': 'RT @aisipos: Is there a way for npm to do an "editable" install like pip does with `pip install -e`? Doesn\'t look like it\'s possible. #node…'}),
#  ('631607673839087616',
#   {'date': '2015-08-12 23:26:18',
#    'hashtags': "['psychology', 'python', 'scrapy', 'wordcloud']",
#    'name': 'Emarsja',
#    'retweets': 0,
#    'text': 'word cloud created by keywords from over 1000 #psychology papers. #python #scrapy #wordcloud http://t.co/3RPvG9QXl0'}),
#  ('631621097142808579',
#   {'date': '2015-08-13 00:19:39',
#    'hashtags': "['SQL', 'Python', 'pandas', 'BigData']",
#    'name': 'bigdataconf',
#    'retweets': 1,
#    'text': 'RT @eddywongch: Who needs #SQL when you have #Python #pandas at @bigdataconf #BigData'}),
#  ('631713826392666112',
#   {'date': '2015-08-13 06:28:07',
#    'hashtags': "['meteorshower', 'python', 'beautiful']",
#    'name': 'NawtyHobbitses',
#    'retweets': 0,
#    'text': 'Our galaxy is only one of millions of billions in this amazing and expanding universe. #meteorshower #python #beautiful'}),
#  ('631626300050948096',
#   {'date': '2015-08-13 00:40:19',
#    'hashtags': "['sportsanalytics', 'dataviz', 'python']",
#    'name': 'HeathNieddu',
#    'retweets': 38,
#    'text': 'RT @lonriesberg: How to Create NBA Shot Charts in Python http://t.co/M7M1fRwVFG #sportsanalytics #dataviz #python http://t.co/BZ0TzdG8q3'}),
#  ('631570999159291904',
#   {'date': '2015-08-12 21:00:34',
#    'hashtags': "['DataScientist', 'Job', 'Hiring', 'DataScience', 'DataMining', 'BigData', 'rstats', 'python', 'Matlab']",
#    'name': 'DataWookie',
#    'retweets': 2,
#    'text': 'RT @hey_anmol: Mousera: #DataScientist http://t.co/DMNPjg8NPi #Job #Hiring #DataScience #DataMining #BigData #rstats #python #Matlab http:/…'}),
#  ('631744827667927040',
#   {'date': '2015-08-13 08:31:18',
#    'hashtags': "['python', 'ipython', 'BigData']",
#    'name': 'BigDataTweetBot',
#    'retweets': 1,
#    'text': 'RT @noiano: "jupyter notebook" is the new "ipython notebook" #python #ipython #BigData  https://t.co/eQjd6C0YsC'}),
#  ('631575047027580928',
#   {'date': '2015-08-12 21:16:39',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python normalize-easy 0.0.3: This package implements normc(), normr() and normv() functions to easily normalize… http://t.co/QStC14ras5'}),
#  ('631747211907461120',
#   {'date': '2015-08-13 08:40:47',
#    'hashtags': "['Python', 'Quantitative', 'jobs']",
#    'name': 'NeuvooAdmBos',
#    'retweets': 0,
#    'text': 'Looking for a #Python #Quantitative Developer – Front Office Market Making Desk #jobs http://t.co/s6NFetsily http://t.co/72SZbPHD20'}),
#  ('631733458167926784',
#   {'date': '2015-08-13 07:46:08',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python ezi 0.2.6: Interface to the Ezidebit payment gateway for credit card and bank account payments. http://t.co/QqEpFZ9p4g'}),
#  ('631627387155972096',
#   {'date': '2015-08-13 00:44:38',
#    'hashtags': "['released', 'python']",
#    'name': 'sdouche',
#    'retweets': 0,
#    'text': 'Cython 0.23 released #released #python - http://t.co/u4uwBZFjiE'}),
#  ('631638811265646592',
#   {'date': '2015-08-13 01:30:02',
#    'hashtags': "['Python']",
#    'name': 'ispmarin',
#    'retweets': 3,
#    'text': "RT @rochacbruno: I'm ashamed of the #Python package system; hacks in setup, weird MANIFEST.in. Too much confusion! when we are moving to a …"}),
#  ('631748799858241536',
#   {'date': '2015-08-13 08:47:05',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python eru-py 0.0.16: ERU client for python http://t.co/ehYpc5DSZZ'}),
#  ('631601144758960128',
#   {'date': '2015-08-12 23:00:22',
#    'hashtags': "['python', 'java', 'python', 'java']",
#    'name': 'retweetjava',
#    'retweets': 4,
#    'text': 'RT @izcoder: Why #python better than #java? b/c when you have wrong base64 padding #python tells you about it. #java just writes random stu…'}),
#  ('631582046595477504',
#   {'date': '2015-08-12 21:44:28',
#    'hashtags': "['python']",
#    'name': 'PythonNorthEast',
#    'retweets': 25,
#    'text': 'RT @ramalhoorg: Not news, but worth spreading: CPython is *way* above average in code quality http://t.co/5AaMdqLczE #python @Coverity @The…'}),
#  ('631737330462818304',
#   {'date': '2015-08-13 08:01:31',
#    'hashtags': "['Snake', 'Albino', 'Burmese', 'Python', 'Malagos', 'Calinan', 'Davao', 'DavaoDelSur', 'Mindanao', 'South', 'Philippines']",
#    'name': 'FrenzyCondoma',
#    'retweets': 0,
#    'text': '#Snake #Albino #Burmese #Python #Malagos #Calinan #Davao #DavaoDelSur #Mindanao #South #Philippines… https://t.co/o5xPhta8ME'}),
#  ('631591150634151940',
#   {'date': '2015-08-12 22:20:39',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python dj-saml-idp 0.20.0: SAML 2.0 IdP for Django http://t.co/a3zy2yDvdy'}),
#  ('631675310975623169',
#   {'date': '2015-08-13 03:55:04',
#    'hashtags': "['MachineLearning', 'Python', 'R']",
#    'name': 'PredictifyMe',
#    'retweets': 0,
#    'text': 'Essentials of Machine Learning Algorithms with Python and R Codes\nhttp://t.co/WUCGKHkBk3\n#MachineLearning #Python #R'}),
#  ('631579484613963776',
#   {'date': '2015-08-12 21:34:17',
#    'hashtags': "['Python']",
#    'name': 'TrendingGithub',
#    'retweets': 0,
#    'text': 'akullpp/awesome-java - A curated list of awesome Java frameworks, libraries and software. Inspired by... https://t.co/tsZ3RY5iej #Python'}),
#  ('631619523666407425',
#   {'date': '2015-08-13 00:13:24',
#    'hashtags': "['sportsanalytics', 'dataviz', 'python']",
#    'name': 'brian915',
#    'retweets': 38,
#    'text': 'RT @lonriesberg: How to Create NBA Shot Charts in Python http://t.co/M7M1fRwVFG #sportsanalytics #dataviz #python http://t.co/BZ0TzdG8q3'}),
#  ('631687460062396416',
#   {'date': '2015-08-13 04:43:21',
#    'hashtags': "['python']",
#    'name': 'vvelikodniy',
#    'retweets': 2,
#    'text': 'RT @pydigest: Asyncio web-парсер от A. Jesse Jiryu Davis и Guido van Rossum: Экосистема asyncio огромная. По ссылке ... http://t.co/psgJyCi…'}),
#  ('631609994643931137',
#   {'date': '2015-08-12 23:35:32',
#    'hashtags': "['Python', 'Ruby', 'Python', 'Node']",
#    'name': 'nodenow',
#    'retweets': 0,
#    'text': 'Sr. #Python Developer. 3+ yrs of professional exp using #Ruby #Python or #Node.js. Start-up experience.\n$100K-$175K\nhttp://t.co/UW3X1GaJmR'}),
#  ('631748827825893376',
#   {'date': '2015-08-13 08:47:12',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python docker-registry-driver-ucloud 0.1.1: Docker registry ucloud storage driver http://t.co/sAsxVXyHBY'}),
#  ('631567383191142400',
#   {'date': '2015-08-12 20:46:12',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python graphite-to-zabbix 0.1.3: This tool allow handle alerts based on graphite metrics. It works as a proxy… http://t.co/iJzB28i5r7'}),
#  ('631677369216950273',
#   {'date': '2015-08-13 04:03:15',
#    'hashtags': "['python']",
#    'name': 'loquamur',
#    'retweets': 2,
#    'text': 'Learning to avoid some bad Python patterns thanks to @TalkPython http://t.co/SfsjIn0T9c #python'}),
#  ('631676185781530625',
#   {'date': '2015-08-13 03:58:33',
#    'hashtags': "['Perl', 'PHP', 'Python', 'thinktank', 'Bangalore', '3Ps', 'startup']",
#    'name': 'R0Nabraham',
#    'retweets': 1,
#    'text': "im thinking of a #Perl, #PHP and #Python #thinktank in #Bangalore like an @Idealab Initiative . i'll call it #3Ps. \n#startup"}),
#  ('631612814990397440',
#   {'date': '2015-08-12 23:46:44',
#    'hashtags': "['Python', 'DataMining']",
#    'name': 'marcel_campelo',
#    'retweets': 0,
#    'text': 'Já que hj está rendendo, bora ali começar mais um na @MSVirtAcademy.\n#Python #DataMining http://t.co/jA4fYWFLkB'}),
#  ('631744165597085696',
#   {'date': '2015-08-13 08:28:40',
#    'hashtags': "['python', 'ipython', 'BigData']",
#    'name': 'noiano',
#    'retweets': 1,
#    'text': '"jupyter notebook" is the new "ipython notebook" #python #ipython #BigData  https://t.co/eQjd6C0YsC'}),
#  ('631748824776601600',
#   {'date': '2015-08-13 08:47:11',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python aliyuncli 1.0.8: Universal Command Line Environment for aliyun http://t.co/wwORIFwx9d'}),
#  ('631620296538107905',
#   {'date': '2015-08-13 00:16:28',
#    'hashtags': "['sportsanalytics', 'dataviz', 'python']",
#    'name': 'GitPrime',
#    'retweets': 38,
#    'text': 'RT @lonriesberg: How to Create NBA Shot Charts in Python http://t.co/M7M1fRwVFG #sportsanalytics #dataviz #python http://t.co/BZ0TzdG8q3'}),
#  ('631657129603125248',
#   {'date': '2015-08-13 02:42:49',
#    'hashtags': "['outreach', 'education', 'Python', 'community']",
#    'name': 'P3Geek',
#    'retweets': 7,
#    'text': 'RT @Podcast__init__: A big thanks to @jessicamckellar for joining us to talk about her work doing #outreach and #education in the #Python #…'}),
#  ('631713264905388033',
#   {'date': '2015-08-13 06:25:53',
#    'hashtags': "['machinehub', 'python', 'opensource', 'FreeCAD', 'bq']",
#    'name': 'Obijuan_cube',
#    'retweets': 3,
#    'text': 'RT @davidsanfal: #machinehub ,a #python webapp to create parametric objects with #opensource tools (#FreeCAD, ...) https://t.co/Stp5lgYUPR …'}),
#  ('631759662472384512',
#   {'date': '2015-08-13 09:30:15',
#    'hashtags': "['python']",
#    'name': 'py3k',
#    'retweets': 1,
#    'text': 'piianalyzer - Analyzing PII in datasets pypi: http://t.co/GfJD4LqAFo www: https://t.co/yyDIPZeEbX #python'}),
#  ('631697240138997760',
#   {'date': '2015-08-13 05:22:13',
#    'hashtags': "['python']",
#    'name': 'TalkPython',
#    'retweets': 2,
#    'text': 'RT @loquamur: Learning to avoid some bad Python patterns thanks to @TalkPython http://t.co/SfsjIn0T9c #python'}),
#  ('631588182941900800',
#   {'date': '2015-08-12 22:08:51',
#    'hashtags': "['Python', 'datascience', 'bigdata', 'analytics', 'ApacheSpark']",
#    'name': 'sumitmund',
#    'retweets': 0,
#    'text': "#Python #datascience #bigdata #analytics #ApacheSpark RT @databricks: From Pandas to @ApacheSpark's DataFrame: http://t.co/jCTDJxAu2c"}),
#  ('631741227864424448',
#   {'date': '2015-08-13 08:17:00',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python connexion 0.8.5: Connexion - API first applications with Swagger and Flask http://t.co/pvTgTSszDc'}),
#  ('631620983959392256',
#   {'date': '2015-08-13 00:19:12',
#    'hashtags': "['python', 'feedly']",
#    'name': 'shimizukawa',
#    'retweets': 0,
#    'text': '"EuroPython 2015: Videos are online" #python #feedly / ここで紹介されてる\nish ライブラリ、おバカで面白かったw 後日のLTでそれをネタにしたライブラリ登場するし楽しかった http://t.co/ximQGZ3Fv0'}),
#  ('631602953175068672',
#   {'date': '2015-08-12 23:07:33',
#    'hashtags': "['IPython', 'Python']",
#    'name': 'being_bayesian',
#    'retweets': 24,
#    'text': 'RT @randal_olson: Big changes w/ the latest #IPython 4.0 release.\n\n"ipython notebook" no longer works?\n\nhttp://t.co/j0MAe0w7fy #Python http…'}),
#  ('631602222934163456',
#   {'date': '2015-08-12 23:04:39',
#    'hashtags': "['Python']",
#    'name': 'TrendingGithub',
#    'retweets': 0,
#    'text': 'kurozael/twitter-contest-bot - Will poll for Retweet Contests and retweet them. Inspired by... https://t.co/xKwlQnLLoj #Python'}),
#  ('631586404867383296',
#   {'date': '2015-08-12 22:01:47',
#    'hashtags': "['Austin', 'Python']",
#    'name': 'ContinuumIO',
#    'retweets': 1,
#    'text': 'Join us tonight in #Austin for the #Python Meetup for a presentation from Kevin Gullikson on his package TelFit: http://t.co/hOfh3gaNXU'}),
#  ('631629045327896576',
#   {'date': '2015-08-13 00:51:14',
#    'hashtags': "['Python', 'SharkValley', 'Everglades', 'CBSMiami']",
#    'name': 'digitalivan',
#    'retweets': 0,
#    'text': '#Python Captured At #SharkValley In #Everglades National Park « #CBSMiami | http://t.co/wdsNoWPSVo http://t.co/GmboeydkEk'}),
#  ('631568945007345664',
#   {'date': '2015-08-12 20:52:25',
#    'hashtags': "['IPython', 'Python']",
#    'name': 'Aashiq_UT',
#    'retweets': 24,
#    'text': 'RT @randal_olson: Big changes w/ the latest #IPython 4.0 release.\n\n"ipython notebook" no longer works?\n\nhttp://t.co/j0MAe0w7fy #Python http…'}),
#  ('631732591473913856',
#   {'date': '2015-08-13 07:42:41',
#    'hashtags': "['python']",
#    'name': 'sugus_etsii',
#    'retweets': 4,
#    'text': 'RT @python_sevilla: #python is awesome! "A curated list of awesome Python frameworks, libraries and software. Inspired by awesome-php." htt…'}),
#  ('631665839888928768',
#   {'date': '2015-08-13 03:17:26',
#    'hashtags': "['python']",
#    'name': 'cloudaus',
#    'retweets': 1,
#    'text': 'Learn #python in 45 minutes https://t.co/9H5iPGHnnQ Phew!'}),
#  ('631648937355689984',
#   {'date': '2015-08-13 02:10:16',
#    'hashtags': "['python']",
#    'name': 'py3k',
#    'retweets': 1,
#    'text': 'jsonte - Json Type Extensions. pypi: http://t.co/s4e31sPuti www: https://t.co/GRMxd8qQBH #python'}),
#  ('631733448982466561',
#   {'date': '2015-08-13 07:46:05',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python easyovs 0.4: Smart tool to manage Neutron rules in OpenStack enviroment http://t.co/09rOIr2fuF'}),
#  ('631719780781789184',
#   {'date': '2015-08-13 06:51:47',
#    'hashtags': "['Python', 'PyCon']",
#    'name': 'hobbestigrou',
#    'retweets': 8,
#    'text': 'RT @PythonWeekly: PyCon Australia 2015 Videos http://t.co/VyzmMQpeyu #Python #PyCon'}),
#  ('631622868032471040',
#   {'date': '2015-08-13 00:26:41',
#    'hashtags': "['livingthedream', 'python', 'sunshine', 'smile', 'snake']",
#    'name': 'NovelGenius',
#    'retweets': 0,
#    'text': 'Wednesday afternoon sunbathing.\n#livingthedream #python #sunshine #smile #snake https://t.co/aoQ6ZJAyID'}),
#  ('631589243115208705',
#   {'date': '2015-08-12 22:13:04',
#    'hashtags': "['Python']",
#    'name': 'ruantux',
#    'retweets': 0,
#    'text': 'Pra quem gosta de #Python\n\nhttps://t.co/c9b1o0iwuy'}),
#  ('631780355058495488',
#   {'date': '2015-08-13 10:52:29',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python Docta 0.2.2: Docta is a new healing docs kit. http://t.co/kEnhxCY1W3'}),
#  ('631563946692997120',
#   {'date': '2015-08-12 20:32:33',
#    'hashtags': "['Python']",
#    'name': 'LILIREVIEWS',
#    'retweets': 0,
#    'text': 'Linguagem #Python – Nível Médio http://t.co/zuJBIB3hGi'}),
#  ('631612497380950016',
#   {'date': '2015-08-12 23:45:28',
#    'hashtags': "['rustlang', 'python']",
#    'name': 'tshepang_dev',
#    'retweets': 0,
#    'text': "@EyalL @rustlang that reminds me, I'm also glad #rustlang went the #python route of snake case for function/method names"}),
#  ('631624576259215360',
#   {'date': '2015-08-13 00:33:28',
#    'hashtags': "['livingthedream', 'python', 'sunshine', 'smile', 'snake']",
#    'name': 'NovelGenius',
#    'retweets': 0,
#    'text': 'Wednesday afternoon sunbathing.\n#livingthedream #python #sunshine #smile #snake https://t.co/aoQ6ZJAyID'}),
#  ('631592167849525248',
#   {'date': '2015-08-12 22:24:41',
#    'hashtags': "['python']",
#    'name': 'drgarcia1986',
#    'retweets': 2,
#    'text': 'RT @fgmacedo: Vídeos da @europython 2015 publicados: https://t.co/sYW0YkmyrL Muito conteúdo bacana e na faixa! #python'}),
#  ('631631372319330304',
#   {'date': '2015-08-13 01:00:28',
#    'hashtags': "['python', 'celery', 'fairSplit', 'globalTimeout', 'exponentialBackoff', 'tasks']",
#    'name': 'x8lucas8x',
#    'retweets': 0,
#    'text': 'Three quick tips from two years with Celery - http://t.co/KGR0TswThP #python #celery #fairSplit #globalTimeout #exponentialBackoff #tasks'}),
#  ('631764449653751808',
#   {'date': '2015-08-13 09:49:17',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python piianalyzer 0.1.0: Analyzing PII in datasets http://t.co/SM5Mhe8Eav'}),
#  ('631601390561824769',
#   {'date': '2015-08-12 23:01:20',
#    'hashtags': "['python', 'rstats', 'igraph']",
#    'name': 'DataWookie',
#    'retweets': 2,
#    'text': 'RT @filmfranz: Analyzing stylistic similarity amongst authors of 12,590 books from @gutenberg_org using #python #rstats &amp; #igraph http://t.…'}),
#  ('631599810945118208',
#   {'date': '2015-08-12 22:55:04',
#    'hashtags': "['Python']",
#    'name': 'MarcoAndrePT',
#    'retweets': 0,
#    'text': 'Linguagem #Python – Nível Médio http://t.co/8jLBNBt99z'}),
#  ('631656647795048448',
#   {'date': '2015-08-13 02:40:55',
#    'hashtags': "['Python']",
#    'name': 'andyvenet',
#    'retweets': 14,
#    'text': 'RT @pycoders: 5 Simple Rules For Building Great #Python Packages http://t.co/mdfKrvcrtb'}),
#  ('631684309468909568',
#   {'date': '2015-08-13 04:30:50',
#    'hashtags': "['Python']",
#    'name': 'fancysandwiches',
#    'retweets': 1,
#    'text': 'Larry Hastings is writing a #Python VM in Python in 6 slides.  MIND = BLOWN'}),
#  ('631766221067841536',
#   {'date': '2015-08-13 09:56:19',
#    'hashtags': "['deeplearning', 'python']",
#    'name': 'aidotech',
#    'retweets': 0,
#    'text': 'RT DominoDataLab: Faster deep learning with GPUs and Theano http://t.co/QR54NTTl8F  #deeplearning #python'}),
#  ('631558993979248641',
#   {'date': '2015-08-12 20:12:52',
#    'hashtags': "['nodejs', 'php', 'ruby', 'python', 'swift', 'java', 'mongodb', 'ang']",
#    'name': 'isurunix',
#    'retweets': 1,
#    'text': 'RT @StackMean: RT crystalcodegen: Why REST at API when Crystal does it all? http://t.co/C1z1seWF4G #nodejs #php #ruby #python #swift #java …'}),
#  ('631624466964066304',
#   {'date': '2015-08-13 00:33:02',
#    'hashtags': "['python', 'pyNews']",
#    'name': 'PyBaltimore',
#    'retweets': 0,
#    'text': 'Best Ever Machine Learning, Python and other Data Science Discussions on Reddit via /r/Python http://t.co/a5ATQX4V2y #python #pyNews'}),
#  ('631677845517955072',
#   {'date': '2015-08-13 04:05:09',
#    'hashtags': "['sportsanalytics', 'dataviz', 'python']",
#    'name': 'wairathimo',
#    'retweets': 38,
#    'text': 'RT @lonriesberg: How to Create NBA Shot Charts in Python http://t.co/M7M1fRwVFG #sportsanalytics #dataviz #python http://t.co/BZ0TzdG8q3'}),
#  ('631711341200326656',
#   {'date': '2015-08-13 06:18:15',
#    'hashtags': "['python', 'code', 'coding']",
#    'name': 'danc0mpton',
#    'retweets': 0,
#    'text': 'Go Watch Now! "learning React/d3 visualization" https://t.co/Z98340FOpL  #python #code #coding @livecodingtv'}),
#  ('631583415238660100',
#   {'date': '2015-08-12 21:49:55',
#    'hashtags': "['python']",
#    'name': 'BigBetAnalytics',
#    'retweets': 2,
#    'text': 'RT @rustyrazorblade: Alright - #python performance profiling video up.  Thanks to everyone that joined the hangout!  https://t.co/KPWygGeuJG'}),
#  ('631558939826614272',
#   {'date': '2015-08-12 20:12:39',
#    'hashtags': "['nodejs', 'php', 'ruby', 'python', 'swift', 'java', 'mongodb', 'ang']",
#    'name': 'StackMean',
#    'retweets': 3,
#    'text': 'RT crystalcodegen: Why REST at API when Crystal does it all? http://t.co/C1z1seWF4G #nodejs #php #ruby #python #swift #java #mongodb #ang…'}),
#  ('631686500430835712',
#   {'date': '2015-08-13 04:39:32',
#    'hashtags': "['BuonGiorno', 'tweepy', 'python']",
#    'name': 'b4d_tR1p',
#    'retweets': 0,
#    'text': '#BuonGiorno mondo crudele! - こんにちは残酷な世界 - #tweepy #python'}),
#  ('631566904637923328',
#   {'date': '2015-08-12 20:44:18',
#    'hashtags': "['python', 'opensource', 'development', 'geek', 'code']",
#    'name': 'trevoirwilliams',
#    'retweets': 0,
#    'text': 'Now the #python way is intriguing me. @Codecademy #opensource #development #geek #code'}),
#  ('631617533498511360',
#   {'date': '2015-08-13 00:05:29',
#    'hashtags': "['IoT', 'deeplearning', 'Python']",
#    'name': 'ElitePPs',
#    'retweets': 1,
#    'text': 'RT @mikegrimshaw2: @ElitePPs Yes, today was a really geeky cool day :-D I LOVE what I do! #IoT #deeplearning #Python'}),
#  ('631772227243933696',
#   {'date': '2015-08-13 10:20:11',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python hgsTools 0.2.50a1: hgsTools Python project http://t.co/2nPJjnV8Io'}),
#  ('631715342050394112',
#   {'date': '2015-08-13 06:34:08',
#    'hashtags': "['Python']",
#    'name': 'Python_Quest',
#    'retweets': 0,
#    'text': 'Python Program with urllib Module http://t.co/Gdebp0dEqq http://t.co/OzK7uFuxAm #Python via @dv_geek'}),
#  ('631570065922629632',
#   {'date': '2015-08-12 20:56:52',
#    'hashtags': "['IPython', 'Python']",
#    'name': 'luk_augustyniak',
#    'retweets': 24,
#    'text': 'RT @randal_olson: Big changes w/ the latest #IPython 4.0 release.\n\n"ipython notebook" no longer works?\n\nhttp://t.co/j0MAe0w7fy #Python http…'}),
#  ('631697659271622657',
#   {'date': '2015-08-13 05:23:53',
#    'hashtags': "['python']",
#    'name': 'mkennedy',
#    'retweets': 3,
#    'text': 'RT @mr_rigden: I found this great podcast about #python called "Talk Python To Me"\nCheck it out.\nhttp://t.co/GbC8eTsavk'}),
#  ('631599362200748032',
#   {'date': '2015-08-12 22:53:17',
#    'hashtags': "['python', 'programming', 'developer']",
#    'name': 'TodoCoders',
#    'retweets': 1,
#    'text': 'RT pythonspot: Learn Python online @ http://t.co/9Mn7TwMrnq   #python #programming #developer'}),
#  ('631612131159379968',
#   {'date': '2015-08-12 23:44:01',
#    'hashtags': "['Python', 'Perl', 'Ruby', 'Burp', 'Fiddler', 'Charles']",
#    'name': 'JobsCoding',
#    'retweets': 0,
#    'text': 'Sr Web App Security Engineer.Scripting #Python #Perl #Ruby\nStrong manual interception proxies #Burp #Fiddler #Charles\nhttp://t.co/MX66ePXWxf'}),
#  ('631579514880032768',
#   {'date': '2015-08-12 21:34:25',
#    'hashtags': "['data', 'Python', 'MessingAroundWithCode']",
#    'name': 'JvCode',
#    'retweets': 0,
#    'text': 'Just filtering through my #data. #Python #MessingAroundWithCode'}),
#  ('631758819899609088',
#   {'date': '2015-08-13 09:26:54',
#    'hashtags': "['python', 'datascience']",
#    'name': 'py_coding',
#    'retweets': 22,
#    'text': 'RT @pycoders: 7 Python Tools All Data Scientists Should Know How to Use http://t.co/vAEDZ3vRoA #python #datascience'}),
#  ('631711215727702016',
#   {'date': '2015-08-13 06:17:45',
#    'hashtags': "['Python']",
#    'name': 'ucb_npwg',
#    'retweets': 3,
#    'text': 'RT @profjsb: Just two days remain to register for the @UCBerkeley #Python bootcamp, August 19-21, open to all: http://t.co/TJ4AYSZbnZ @UCBI…'}),
#  ('631731843478482944',
#   {'date': '2015-08-13 07:39:43',
#    'hashtags': "['Python']",
#    'name': 'jcorrius',
#    'retweets': 6,
#    'text': 'RT @ManAHLTech: 10+ reasons for moving to Python 3 http://t.co/QOEEvx25Ao @gmarkall @ianozsvald #Python'}),
#  ('631595095301693440',
#   {'date': '2015-08-12 22:36:19',
#    'hashtags': "['Python']",
#    'name': 'propheticus',
#    'retweets': 12,
#    'text': 'RT @pycoders: Optimizing #Python - A Case Study http://t.co/ZSOd1TvIZr'}),
#  ('631741224865501184',
#   {'date': '2015-08-13 08:16:59',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python fastavro 0.8.6: Fast iteration of AVRO files http://t.co/5UMdJ1SVCl'}),
#  ('631676747956682752',
#   {'date': '2015-08-13 04:00:47',
#    'hashtags': "['python']",
#    'name': 'laoyang945',
#    'retweets': 2,
#    'text': 'RT @akid_: [北京]「25-40k」社交初创团队寻高级 Python 工程师 http://t.co/HmYbGqTvJa #python'}),
#  ('631583577713590276',
#   {'date': '2015-08-12 21:50:33',
#    'hashtags': "['python', 'Latex']",
#    'name': 'Datapolitan',
#    'retweets': 0,
#    'text': 'Discovered another great use for @ProjectJupyter (besides creating great #python code): creating #Latex on the fly http://t.co/FG2eSeXbh6'}),
#  ('631763028908896256',
#   {'date': '2015-08-13 09:43:38',
#    'hashtags': "['github', 'python', 'journos', 'ddj']",
#    'name': 'zehnzehen',
#    'retweets': 2,
#    'text': '#github + #python tutorials for #journos  #ddj http://t.co/PMB4NiU2EM - by @Uuuna'}),
#  ('631592272346394624',
#   {'date': '2015-08-12 22:25:06',
#    'hashtags': "['Python', 'jobs']",
#    'name': 'coding_jobfeeds',
#    'retweets': 0,
#    'text': '#Python #jobs PYTHON SOFTWARE ENGINEER http://t.co/lSBu1LZOMH Fort Lauderdale'}),
#  ('631737144847962112',
#   {'date': '2015-08-13 08:00:47',
#    'hashtags': "['python', 'rstats', 'igraph']",
#    'name': 'DataWookie',
#    'retweets': 1,
#    'text': 'RT @algoritmic: Analyzing stylistic similarity amongst authors @gutenberg_org using #python #rstats #igraph http://t.co/j8Ys1v1hpr http://t…'}),
#  ('631606976905117696',
#   {'date': '2015-08-12 23:23:32',
#    'hashtags': "['Python', 'Quantitative', 'jobs']",
#    'name': 'NeuvooAdmBos',
#    'retweets': 0,
#    'text': 'Looking for a #Python #Quantitative Developer – Front Office Market Making Desk #jobs http://t.co/eVpv62XrDU'}),
#  ('631582959359791104',
#   {'date': '2015-08-12 21:48:06',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python django-tribe-client 1.0.5: Reusable Django app to connect servers with the Tribe web service at Dartmouth… http://t.co/kAlCP9p7WC'}),
#  ('631608571818582017',
#   {'date': '2015-08-12 23:29:52',
#    'hashtags': "['MongoDB', 'python']",
#    'name': 'StackMean',
#    'retweets': 0,
#    'text': 'RT emschuch: today at school: practicing #MongoDB + #python with a very serious dataset.  thisismetis http://t.co/thFS8mHTkn'}),
#  ('631623007727931392',
#   {'date': '2015-08-13 00:27:14',
#    'hashtags': "['sportsanalytics', 'dataviz', 'python']",
#    'name': 't_pren',
#    'retweets': 38,
#    'text': 'RT @lonriesberg: How to Create NBA Shot Charts in Python http://t.co/M7M1fRwVFG #sportsanalytics #dataviz #python http://t.co/BZ0TzdG8q3'}),
#  ('631731775845343232',
#   {'date': '2015-08-13 07:39:27',
#    'hashtags': "['udemy', 'python', 'technology']",
#    'name': 'MarketACourse',
#    'retweets': 0,
#    'text': 'http://t.co/v7O0l40xcu - Python for Beginners  #udemy #python #technology http://t.co/S4QK0QPjcO'}),
#  ('631709773407330304',
#   {'date': '2015-08-13 06:12:01',
#    'hashtags': "['Python', 'MachineLearning']",
#    'name': 'itknowingness',
#    'retweets': 6,
#    'text': 'RT @pivotal: If you work in #Python or #MachineLearning - join us for a hands-on workshop in London http://t.co/O1x3sJ6FsZ http://t.co/g6xp…'}),
#  ('631669599704997888',
#   {'date': '2015-08-13 03:32:23',
#    'hashtags': "['python']",
#    'name': 'Actually_Shant',
#    'retweets': 5,
#    'text': 'RT @SecurityTube: Script Attack &amp; Pentest tools using Python from the very basics: http://t.co/CxZwWl3fPy #python'}),
#  ('631573607492104193',
#   {'date': '2015-08-12 21:10:56',
#    'hashtags': "['حرفياً', 'LadyDior', 'python', 'Salmon', 'Luxury', 'dusseldorf']",
#    'name': 'in1li',
#    'retweets': 1,
#    'text': 'RT @Al_Ketbi: هلا بالغالية #حرفياً 😅😍💋❤️ \n\n#LadyDior #python #Salmon #Luxury #dusseldorf http://t.co/ZGHLXQkojp'}),
#  ('631605718240485377',
#   {'date': '2015-08-12 23:18:32',
#    'hashtags': "['Python', 'Ruby', 'AWS', 'Linux', 'Unix', 'CalgaryJobs', 'AlbertaJobs', 'Canada', 'CanadaTechJobs', 'Tech', 'Job']",
#    'name': 'JobsFromLanger',
#    'retweets': 0,
#    'text': '#Python #Ruby #AWS #Linux #Unix experience? @CiscoSecurity has 15+ Openings in #CalgaryJobs #AlbertaJobs #Canada. #CanadaTechJobs #Tech #Job'}),
#  ('631573040774537216',
#   {'date': '2015-08-12 21:08:41',
#    'hashtags': "['IPython', 'Python']",
#    'name': 'dasaptaerwin',
#    'retweets': 24,
#    'text': 'RT @randal_olson: Big changes w/ the latest #IPython 4.0 release.\n\n"ipython notebook" no longer works?\n\nhttp://t.co/j0MAe0w7fy #Python http…'}),
#  ('631574675290746881',
#   {'date': '2015-08-12 21:15:11',
#    'hashtags': "['python']",
#    'name': 'pycoders',
#    'retweets': 4,
#    'text': 'Gesture Typing - by Peter Norvig. http://t.co/1fIvjohX8C #python'}),
#  ('631764440245932033',
#   {'date': '2015-08-13 09:49:14',
#    'hashtags': "['python']",
#    'name': 'GISPyQuestions',
#    'retweets': 0,
#    'text': 'QGIS Python Identify Locations within a Polygon http://t.co/98lKP3usve #python'}),
#  ('631562636652457984',
#   {'date': '2015-08-12 20:27:21',
#    'hashtags': "['python', 'softwaredevelopment']",
#    'name': 'LenaertsDaan',
#    'retweets': 0,
#    'text': 'Python 3.4: Execute function every five seconds http://t.co/8vV2JierzH  #python #softwaredevelopment'}),
#  ('631607689311875072',
#   {'date': '2015-08-12 23:26:22',
#    'hashtags': "['python']",
#    'name': 'masayang',
#    'retweets': 0,
#    'text': '「Executing javascripts inside webkit frame is one of the most interesting features provided by Ghost:」\u3000#python\nhttp://t.co/ed0KzuTmBn'}),
#  ('631604234438475776',
#   {'date': '2015-08-12 23:12:38',
#    'hashtags': "['Python', 'python']",
#    'name': 'bostonpython',
#    'retweets': 15,
#    'text': 'RT @pycoders: A Neural Network in 11 lines of #Python http://t.co/6AAaWV2n7u #python'}),
#  ('631710227629539328',
#   {'date': '2015-08-13 06:13:49',
#    'hashtags': "['python']",
#    'name': 'pythontrending',
#    'retweets': 1,
#    'text': "DAT7 - General Assembly's Data Science course in Washington, DC http://t.co/nA5VzhsALH #python"}),
#  ('631745879666507776',
#   {'date': '2015-08-13 08:35:29',
#    'hashtags': "['deeplearning', 'python']",
#    'name': 'aidotech',
#    'retweets': 0,
#    'text': 'RT DominoDataLab: Faster deep learning with GPUs and Theano http://t.co/QR54NTTl8F  #deeplearning #python'}),
#  ('631782298879401984',
#   {'date': '2015-08-13 11:00:12',
#    'hashtags': "['python']",
#    'name': 'py_nsk',
#    'retweets': 0,
#    'text': '#python / Python оптимизации: сверхоптимизация кода на Python /  / http://t.co/Em0x6ar4GR http://t.co/GeQYDhzcdL'}),
#  ('631759153036423168',
#   {'date': '2015-08-13 09:28:14',
#    'hashtags': "['Django', 'Python']",
#    'name': 'milanpecov',
#    'retweets': 0,
#    'text': 'DjangoCon Europe 2015 talks are now online | https://t.co/mtNwyRvQSx #Django #Python'}),
#  ('631722633969561601',
#   {'date': '2015-08-13 07:03:07',
#    'hashtags': "['Python']",
#    'name': 'angel_lb',
#    'retweets': 0,
#    'text': 'Aprende a configurar todo lo necesario para ponerte manos a la obra con #Python y @Minecraft. Genial ! https://t.co/kC0tf8XT0s'}),
#  ('631620194373210114',
#   {'date': '2015-08-13 00:16:03',
#    'hashtags': "['sportsanalytics', 'dataviz', 'python']",
#    'name': 'rajandatta',
#    'retweets': 38,
#    'text': 'RT @lonriesberg: How to Create NBA Shot Charts in Python http://t.co/M7M1fRwVFG #sportsanalytics #dataviz #python http://t.co/BZ0TzdG8q3'}),
#  ('631784860298924032',
#   {'date': '2015-08-13 11:10:23',
#    'hashtags': "['deeplearning', 'python']",
#    'name': 'IntelligenceTV',
#    'retweets': 6,
#    'text': 'RT @DominoDataLab: Faster deep learning with GPUs and Theano http://t.co/qTvY6MWcJ0  #deeplearning #python'}),
#  ('631570858121797632',
#   {'date': '2015-08-12 21:00:01',
#    'hashtags': "['datascience', 'python', 'rstats']",
#    'name': 'DominoDataLab',
#    'retweets': 3,
#    'text': 'Deep Learning with @h2oai http://t.co/0AR8ln8kJg #datascience #python #rstats'}),
#  ('631729543825461249',
#   {'date': '2015-08-13 07:30:34',
#    'hashtags': "['Python', 'IBMi']",
#    'name': 'Proximity_ltd',
#    'retweets': 1,
#    'text': 'Get rolling with #Python on #IBMi http://t.co/xxOLGzLrUu via @aaronbartell in @IBMimag'}),
#  ('631762257651761152',
#   {'date': '2015-08-13 09:40:34',
#    'hashtags': "['Python']",
#    'name': 'Python_Quest',
#    'retweets': 0,
#    'text': 'Rounding error in generating perfect squares python http://t.co/kTOU9kcFWa http://t.co/ZyamC6nu28 #Python via @dv_geek'}),
#  ('631586131511873536',
#   {'date': '2015-08-12 22:00:42',
#    'hashtags': "['Python', 'DataScience', 'SODS']",
#    'name': 'g_joseph_m',
#    'retweets': 7,
#    'text': 'RT @MikeTamir: Pyxley: #Python Powered Dashboards http://t.co/Y63GPjZVPs #DataScience #SODS http://t.co/0WzuKNK1Jz'}),
#  ('631587440323657735',
#   {'date': '2015-08-12 22:05:54',
#    'hashtags': "['python', 'nlp']",
#    'name': '123hypnosis',
#    'retweets': 3,
#    'text': 'RT @GrimmScientist: Synonyms with directionality!  http://t.co/dTZjYi5ERH  #python #nlp'}),
#  ('631593849383690241',
#   {'date': '2015-08-12 22:31:22',
#    'hashtags': "['python', 'programming', 'developer']",
#    'name': 'pythonspot',
#    'retweets': 1,
#    'text': 'Learn Python online @ http://t.co/COZgsG0THc   #python #programming #developer'}),
#  ('631675513849937920',
#   {'date': '2015-08-13 03:55:53',
#    'hashtags': "['python']",
#    'name': 'LeahAWasser',
#    'retweets': 0,
#    'text': 'hey @datacarpentry #python friends. how do you force matplotlib 2 plot in new window rather than inline? new setup is defaulting inline'}),
#  ('631777431712567296',
#   {'date': '2015-08-13 10:40:52',
#    'hashtags': "['python']",
#    'name': 'tobixx',
#    'retweets': 0,
#    'text': '@lynncrees are you the author of the #python shove module? Discontinued development? Want to shift the responsibility?'}),
#  ('631619394620256257',
#   {'date': '2015-08-13 00:12:53',
#    'hashtags': "['sportsanalytics', 'dataviz', 'python']",
#    'name': 'humidbeing',
#    'retweets': 38,
#    'text': 'RT @lonriesberg: How to Create NBA Shot Charts in Python http://t.co/M7M1fRwVFG #sportsanalytics #dataviz #python http://t.co/BZ0TzdG8q3'}),
#  ('631595493768957952',
#   {'date': '2015-08-12 22:37:54',
#    'hashtags': "['python']",
#    'name': 'PythonGossip',
#    'retweets': 25,
#    'text': 'RT @ramalhoorg: Not news, but worth spreading: CPython is *way* above average in code quality http://t.co/5AaMdqLczE #python @Coverity @The…'}),
#  ('631689561240903680',
#   {'date': '2015-08-13 04:51:42',
#    'hashtags': "['Python', 'HowTo']",
#    'name': 'wbulletins',
#    'retweets': 0,
#    'text': '#Python file deletion takes a long time to delete files\n#HowTo\nhttp://t.co/RjLpcAvsLd'}),
#  ('631658335595569152',
#   {'date': '2015-08-13 02:47:37',
#    'hashtags': "['Python']",
#    'name': 'jpmieville',
#    'retweets': 14,
#    'text': 'RT @pycoders: 5 Simple Rules For Building Great #Python Packages http://t.co/mdfKrvcrtb'}),
#  ('631758753277345792',
#   {'date': '2015-08-13 09:26:38',
#    'hashtags': "['IPython', 'Python']",
#    'name': 'py_coding',
#    'retweets': 24,
#    'text': 'RT @randal_olson: Big changes w/ the latest #IPython 4.0 release.\n\n"ipython notebook" no longer works?\n\nhttp://t.co/j0MAe0w7fy #Python http…'}),
#  ('631619691686010880',
#   {'date': '2015-08-13 00:14:04',
#    'hashtags': "['sportsanalytics', 'dataviz', 'python']",
#    'name': 'v36ar',
#    'retweets': 38,
#    'text': 'RT @lonriesberg: How to Create NBA Shot Charts in Python http://t.co/M7M1fRwVFG #sportsanalytics #dataviz #python http://t.co/BZ0TzdG8q3'}),
#  ('631614837395578880',
#   {'date': '2015-08-12 23:54:46',
#    'hashtags': "['Flask', 'rethinkdb', 'Python']",
#    'name': 'RealPython',
#    'retweets': 1,
#    'text': 'RT @JvCode: @RealPython Wrote a great post on @rethinkdb and #Flask. A great way to start error handling w/#rethinkdb. #Python'}),
#  ('631608195740360704',
#   {'date': '2015-08-12 23:28:23',
#    'hashtags': "['RoR', 'Python']",
#    'name': 'JobsCoding',
#    'retweets': 0,
#    'text': 'Analytics Engineer. Extensive exp w/ statistical analysis.Experience in software dev using #RoR or #Python\n$80K-$130K\nhttp://t.co/rJyxsAMZeq'}),
#  ('631766677416484864',
#   {'date': '2015-08-13 09:58:08',
# ...
#  ('631607421841076225',
#   {'date': '2015-08-12 23:25:18',
#    'hashtags': "['Gcat', 'backdoor', 'Python', 'Gmail', 'infórmate']",
#    'name': 'CIDsecureLoja',
#    'retweets': 0,
#    'text': '#Gcat, un #backdoor escrito en #Python que utiliza #Gmail como C&amp;C http://t.co/3g7tsPugqR #infórmate http://t.co/R53ilEMOmb'}),
#  ('631764438622728192',
#   {'date': '2015-08-13 09:49:14',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python kineticlib 1.6: Library for kinetic theory calculations in the multi-temperature and state-to-state… http://t.co/Dz2gDksOoC'}),
#  ('631641076139458560',
#   {'date': '2015-08-13 01:39:02',
#    'hashtags': "['Python']",
#    'name': 'pedrocorreianet',
#    'retweets': 1,
#    'text': 'RT @airpair: Optimizing #Python - a Case Study @ThePSF by @ryan_sb http://t.co/TtcYshtZYR http://t.co/DjMKCaLTPh'}),
#  ('631698038923395072',
#   {'date': '2015-08-13 05:25:23',
#    'hashtags': "['glitchart', 'python', 'coding', 'RaspberryPi']",
#    'name': 'NoahKantor',
#    'retweets': 0,
#    'text': 'I made a twitterbot that absolutely loves #glitchart! Say hello, @MadKantor! #python #coding #RaspberryPi'}),
#  ('631567376916484096',
#   {'date': '2015-08-12 20:46:11',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python dataone.generic_member_node 1.2.2a5: DataONE Generic Member Node (GMN) http://t.co/YHIFoKVriD'}),
#  ('631589967198855169',
#   {'date': '2015-08-12 22:15:57',
#    'hashtags': "['python', 'maula']",
#    'name': 'blispr',
#    'retweets': 0,
#    'text': "This uplifts me [ sing (tune) for tune in {any religion) ].  But I cannot 'comprehend' the fear psychosis created by media. #python #maula"}),
#  ('631582376041295872',
#   {'date': '2015-08-12 21:45:47',
#    'hashtags': "['python']",
#    'name': 'py3k',
#    'retweets': 0,
#    'text': 'langid - langid.py is a standalone Language Identification (LangID) tool. pypi: http://t.co/jsfWX0pnzQ www: https://t.co/1qAAkEObVq #python'}),
#  ('631668638420832256',
#   {'date': '2015-08-13 03:28:33',
#    'hashtags': "['Python']",
#    'name': 'Python_Quest',
#    'retweets': 0,
#    'text': "OpenCV 3, python 3 'Image step is wrong' error http://t.co/fAovjefPSP http://t.co/dic59HHM1F #Python via @dv_geek"}),
#  ('631628745162428416',
#   {'date': '2015-08-13 00:50:02',
#    'hashtags': "['python']",
#    'name': 'taoeffect',
#    'retweets': 0,
#    'text': '@random_walker Probably doesn’t work as well for #python? 😉'}),
#  ('631748808448176128',
#   {'date': '2015-08-13 08:47:07',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python dossier.models 0.6.17.dev32: Active learning models http://t.co/E9hYPY02BU'}),
#  ('631721953204785152',
#   {'date': '2015-08-13 07:00:25',
#    'hashtags': "['Python']",
#    'name': 'ManAHLTech',
#    'retweets': 6,
#    'text': '10+ reasons for moving to Python 3 http://t.co/QOEEvx25Ao @gmarkall @ianozsvald #Python'}),
#  ('631752524484100096',
#   {'date': '2015-08-13 09:01:53',
#    'hashtags': "['EuroPython', 'python', 'restapis', 'api', 'cloud', 'bigdata', 'visualisation']",
#    'name': 'BigDataTweetBot',
#    'retweets': 1,
#    'text': 'RT @AdmaticMarTech: #EuroPython 2015 talk videos are now online ~ @europython https://t.co/p5EWIMikSJ #python #restapis #api #cloud #bigdat…'}),
#  ('631602594410950658',
#   {'date': '2015-08-12 23:06:07',
#    'hashtags': "['python']",
#    'name': 'bitprophet',
#    'retweets': 25,
#    'text': 'RT @ramalhoorg: Not news, but worth spreading: CPython is *way* above average in code quality http://t.co/5AaMdqLczE #python @Coverity @The…'}),
#  ('631621441385951232',
#   {'date': '2015-08-13 00:21:01',
#    'hashtags': "['Python', 'RubyonRails', 'LAMP']",
#    'name': 'JobsCoding',
#    'retweets': 0,
#    'text': 'DevOps Engineer. Extensive Programming knowledge working w/ (#Python, #RubyonRails, and/or #LAMP stack)\n$100K-$150K\nhttp://t.co/DMOnJv5aTi'}),
#  ('631575497051222016',
#   {'date': '2015-08-12 21:18:27',
#    'hashtags': "['Python']",
#    'name': 'JvCode',
#    'retweets': 1,
#    'text': 'RT @Python_Quest: Namespace issue with pysaml2 XML canonicalization http://t.co/v3oVw78mVe http://t.co/UWGB8yHNPk #Python via @dv_geek'}),
#  ('631658551283445760',
#   {'date': '2015-08-13 02:48:28',
#    'hashtags': "['python']",
#    'name': 'Aid_Rostov',
#    'retweets': 5,
#    'text': 'RT @SecurityTube: Script Attack &amp; Pentest tools using Python from the very basics: http://t.co/CxZwWl3fPy #python'}),
#  ('631646564906344448',
#   {'date': '2015-08-13 02:00:51',
#    'hashtags': "['python', 'techtalk']",
#    'name': 'imjessicayuen',
#    'retweets': 1,
#    'text': 'Python meetup and tech talks happening at the Yelp building right now! #python #techtalk http://t.co/UfVsUtLJzl'}),
#  ('631747318669307904',
#   {'date': '2015-08-13 08:41:12',
#    'hashtags': "['python', 'soundtrack', 'game', 'raspberrypi']",
#    'name': 'ProjectPyland',
#    'retweets': 4,
#    'text': 'A quick look at the fantastic work done by @alexandaday on our soundtrack! https://t.co/Bh0lAPRnIH #python #soundtrack #game #raspberrypi'}),
#  ('631759217385414656',
#   {'date': '2015-08-13 09:28:29',
#    'hashtags': "['informatica', 'programacion', 'Python']",
#    'name': 'conectabell',
#    'retweets': 0,
#    'text': '#informatica #programacion #Python Instalar Wordpress con Python - http://t.co/ytZyintENy http://t.co/wy2LFKqhGm'}),
#  ('631615154342502400',
#   {'date': '2015-08-12 23:56:02',
#    'hashtags': "['Python', 'Flask', 'framework']",
#    'name': 'ubuntroll',
#    'retweets': 5,
#    'text': 'RT @ozgurorman: http://t.co/3eFRMgFAb6 Good intro. about #Python #Flask #framework'}),
#  ('631739176887681024',
#   {'date': '2015-08-13 08:08:51',
#    'hashtags': "['MachineLearning', 'Algorithms', 'Python', 'R', 'informatics']",
#    'name': 'dexstr_tsc',
#    'retweets': 0,
#    'text': 'Essentials of #MachineLearning #Algorithms (with #Python and #R Codes) | via @kunlqt http://t.co/Jt1D0gsNlJ #informatics'}),
#  ('631575504630513665',
#   {'date': '2015-08-12 21:18:29',
#    'hashtags': "['job', 'webdev', 'frontend', 'developer', 'nodejs', 'python', 'ruby']",
#    'name': 'nodenow',
#    'retweets': 0,
#    'text': 'We are hiring: Senior Web Development Engine http://t.co/7P3ywLmf25 #job awscloud #webdev #frontend #developer #nodejs #python #ruby'}),
#  ('631663809099354112',
#   {'date': '2015-08-13 03:09:22',
#    'hashtags': "['IPython', 'Python']",
#    'name': 'ag_shen',
#    'retweets': 24,
#    'text': 'RT @randal_olson: Big changes w/ the latest #IPython 4.0 release.\n\n"ipython notebook" no longer works?\n\nhttp://t.co/j0MAe0w7fy #Python http…'}),
#  ('631658583151632384',
#   {'date': '2015-08-13 02:48:36',
#    'hashtags': "['Python', 'Ruby', 'Php', 'Java', 'HTML5']",
#    'name': 'akki0405',
#    'retweets': 3,
#    'text': 'RT @Absolut_Valium: Willing to learn how to code? Have a look on these recommendations for #Python, #Ruby, #Php #Java and #HTML5... http://…'}),
#  ('631571564287422464',
#   {'date': '2015-08-12 21:02:49',
#    'hashtags': "['IPython', 'Python']",
#    'name': 'hidden_node',
#    'retweets': 24,
#    'text': 'RT @randal_olson: Big changes w/ the latest #IPython 4.0 release.\n\n"ipython notebook" no longer works?\n\nhttp://t.co/j0MAe0w7fy #Python http…'}),
#  ('631741221841453056',
#   {'date': '2015-08-13 08:16:59',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 1,
#    'text': '#python pyepm 1.0.2: Python Ethereum Package Manager http://t.co/Yy45Sn9TAm'}),
#  ('631623423588986882',
#   {'date': '2015-08-13 00:28:53',
#    'hashtags': "['python']",
#    'name': '4n68r',
#    'retweets': 7,
#    'text': 'RT @pythontrending: CredCrack - A fast and stealthy credential harvester http://t.co/L5CoKF2Obu #python'}),
#  ('631701220705460224',
#   {'date': '2015-08-13 05:38:02',
#    'hashtags': "['RSS', 'Python', 'NodeJS', 'yahoopipes']",
#    'name': 'Numegital',
#    'retweets': 2,
#    'text': 'RT @RSSCircus: [#RSS] Export your private [Yahoo] Pipes and convert them in #Python or #NodeJS | @scoopit http://t.co/DDBTfpsC3z #yahoopipes'}),
#  ('631715335402491904',
#   {'date': '2015-08-13 06:34:07',
#    'hashtags': "['Python']",
#    'name': 'Python_Quest',
#    'retweets': 0,
#    'text': 'Type Error: Int object is not callable http://t.co/IyvKfK1rz5 http://t.co/hojIstMgp5 #Python via @dv_geek'}),
#  ('631773132949471232',
#   {'date': '2015-08-13 10:23:47',
#    'hashtags': "['python']",
#    'name': 'GurzoLegend',
#    'retweets': 66,
#    'text': 'RT @raymondh: #python food for thought:\n"I would never read a file into a string and exec it, that would dangerous!"\n"But I use imports all…'}),
#  ('631666039420514304',
#   {'date': '2015-08-13 03:18:14',
#    'hashtags': "['outreach', 'education', 'Python', 'community']",
#    'name': 'JvCode',
#    'retweets': 7,
#    'text': 'RT @Podcast__init__: A big thanks to @jessicamckellar for joining us to talk about her work doing #outreach and #education in the #Python #…'}),
#  ('631602689735041024',
#   {'date': '2015-08-12 23:06:30',
#    'hashtags': "['Memex', 'PyData', 'Python']",
#    'name': 'LarryGray',
#    'retweets': 2,
#    'text': 'RT @ContinuumIO: #Memex - Mining the Dark Web - see the talk from Data Scientist Katrina Riehl at #PyData Seattle here: http://t.co/hOPXM2R…'}),
#  ('631575019278110720',
#   {'date': '2015-08-12 21:16:33',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python dataone.generic_member_node 1.2.2a6: DataONE Generic Member Node (GMN) http://t.co/z2eiEz92iI'}),
#  ('631764456477868033',
#   {'date': '2015-08-13 09:49:18',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python gittraffic 0.0.17: Using a CRON, follow your git traffic per package http://t.co/dgqgOC3z67'}),
#  ('631572504507777024',
#   {'date': '2015-08-12 21:06:33',
#    'hashtags': "['job', 'webdev', 'frontend', 'developer', 'nodejs', 'python', 'ruby']",
#    'name': 'TodoCoders',
#    'retweets': 0,
#    'text': 'We are hiring: Senior Web Development Engine http://t.co/nD2FnY4uFd #job awscloud #webdev #frontend #developer #nodejs #python #ruby'}),
#  ('631640190361182208',
#   {'date': '2015-08-13 01:35:31',
#    'hashtags': "['js', 'python', 'bootstrap', 'postgresql', 'jobs']",
#    'name': 'BXCert',
#    'retweets': 0,
#    'text': 'Веб - разработчик. Москва. #js #python #bootstrap #postgresql #jobs http://t.co/SuIbnVfETz http://t.co/u0tWmo5wcS'}),
#  ('631575041440788480',
#   {'date': '2015-08-12 21:16:38',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python graphite-to-zabbix 0.1.5: This tool allow handle alerts based on graphite metrics. It works as a proxy… http://t.co/uTOtfO1sce'}),
#  ('631612290152972288',
#   {'date': '2015-08-12 23:44:39',
#    'hashtags': "['MongoDB', 'python']",
#    'name': 'StackMean',
#    'retweets': 0,
#    'text': 'RT emschuch: today at school: practicing #MongoDB + #python with a very serious dataset.  thisismetis http://t.co/thFS8mHTkn'}),
#  ('631631739102871552',
#   {'date': '2015-08-13 01:01:56',
#    'hashtags': "['leather', 'sandals', 'Livas', 'Homme', 'python']",
#    'name': 'dearosaathens',
#    'retweets': 0,
#    'text': "He's checked in @hotelcroydon with our men's #leather #sandals and #Livas #Homme in #python exclusively available... http://t.co/EfSAK7CLaD"}),
#  ('631569051370700800',
#   {'date': '2015-08-12 20:52:50',
#    'hashtags': "['IPython', 'Python']",
#    'name': 'crisantogalay',
#    'retweets': 24,
#    'text': 'RT @randal_olson: Big changes w/ the latest #IPython 4.0 release.\n\n"ipython notebook" no longer works?\n\nhttp://t.co/j0MAe0w7fy #Python http…'}),
#  ('631725445331836928',
#   {'date': '2015-08-13 07:14:17',
#    'hashtags': "['python']",
#    'name': 'caleb_hattingh',
#    'retweets': 1,
#    'text': 'RT @cloudaus: Learn #python in 45 minutes https://t.co/9H5iPGHnnQ Phew!'}),
#  ('631732104917860352',
#   {'date': '2015-08-13 07:40:45',
#    'hashtags': "['linux', 'python']",
#    'name': 'k3u1t2y8x9i',
#    'retweets': 16,
#    'text': 'RT @pythontrending: subuser - Run programs in linux with selectively restricted permissions. http://t.co/q5OTAD0MFu #linux #python'}),
#  ('631622269819858945',
#   {'date': '2015-08-13 00:24:18',
#    'hashtags': "['python']",
#    'name': 'P3Geek',
#    'retweets': 1,
#    'text': 'RT @kthotav: https://t.co/4vhlERYHDb\nNice tutorial and documentation for learning #python.'}),
#  ('631583104600178689',
#   {'date': '2015-08-12 21:48:41',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python langid 1.1.5: langid.py is a standalone Language Identification (LangID) tool. http://t.co/i4x1M8ua3A'}),
#  ('631725267770175488',
#   {'date': '2015-08-13 07:13:35',
#    'hashtags': "['python']",
#    'name': 'artwisanggeni',
#    'retweets': 0,
#    'text': '#python WeChatPay 1.1.4: Python-Django WeChat payment API. http://t.co/BrmVbysgtC'}),
#  ('631624739103068160',
#   {'date': '2015-08-13 00:34:07',
#    'hashtags': "['sportsanalytics', 'dataviz', 'python']",
#    'name': 'MollyMacauley',
#    'retweets': 38,
#    'text': 'RT @lonriesberg: How to Create NBA Shot Charts in Python http://t.co/M7M1fRwVFG #sportsanalytics #dataviz #python http://t.co/BZ0TzdG8q3'}),
#  ('631669270418751488',
#   {'date': '2015-08-13 03:31:04',
#    'hashtags': "['Python']",
#    'name': 'wbulletins',
#    'retweets': 0,
#    'text': '#Python + JSON serialization for MD5 hash - how can I guarantee that two equivalent objects will serialize to exac… http://t.co/U0l9EYaM6g'}),
#  ('631756748634910720',
#   {'date': '2015-08-13 09:18:41',
#    'hashtags': "['python', 'HowTo']",
#    'name': 'wbulletins',
#    'retweets': 0,
#    'text': '#python, how to know the week number of the day, Saturday as the first day of the week\n#HowTo\nhttp://t.co/FzOuzvb2Pe'}),
#  ('631629220565921792',
#   {'date': '2015-08-13 00:51:55',
#    'hashtags': "['Senior', 'Python', 'Nashville', 'jobs']",
#    'name': 'NeuvooEngNas',
#    'retweets': 0,
#    'text': 'Medical City is hiring! #Senior #Python/ Perl/ Splunk Security Engineer in #Nashville, apply now! #jobs http://t.co/c8buKavpj6'}),
#  ('631656542052438016',
#   {'date': '2015-08-13 02:40:29',
#    'hashtags': "['python']",
#    'name': 'SecurityTube',
#    'retweets': 5,
#    'text': 'Script Attack &amp; Pentest tools using Python from the very basics: http://t.co/CxZwWl3fPy #python'}),
#  ('631778242676961280',
#   {'date': '2015-08-13 10:44:05',
#    'hashtags': "['Python']",
#    'name': 'Python_Quest',
#    'retweets': 0,
#    'text': 'Specifying exact Python version for Travis CI in combination with tox http://t.co/KfYBZ70Zdd http://t.co/BwRAvk9kSp #Python via @dv_geek'}),
#  ('631746653842632706',
#   {'date': '2015-08-13 08:38:34',
#    'hashtags': "['Python']",
#    'name': 'Python_Quest',
#    'retweets': 0,
#    'text': 'Queue empty after exiting function python http://t.co/EFWHQmpIyH http://t.co/lKp3Iz22yF #Python via @dv_geek'}),
#  ('631580463417548800',
#   {'date': '2015-08-12 21:38:11',
#    'hashtags': "['Python', 'Azure']",
#    'name': 'Darthgreg78',
#    'retweets': 26,
#    'text': "RT @VisualStudio: ...so you're having trouble debugging a #Python Web app in #Azure Web Apps? This may help: http://t.co/4CTIuRwpfL http://…"}),
#  ('631660870968442880',
#   {'date': '2015-08-13 02:57:41',
#    'hashtags': "['nodejs', 'python']",
#    'name': 'TechWars_io',
#    'retweets': 0,
#    'text': 'We compared #nodejs vs #python - see results: http://t.co/wumq6eSaVr'}),
#  ('631676566444077056',
#   {'date': '2015-08-13 04:00:04',
#    'hashtags': "['Perl', 'PHP', 'Python', 'thinktank', 'Bangalore', '3Ps', 'startup']",
#    'name': 'tweets_develop',
#    'retweets': 0,
#    'text': "RT @R0Nabraham im thinking of a #Perl, #PHP and #Python #thinktank in #Bangalore like an @Idealab Initiative . i'll call it #3Ps. \n#startup"}),
#  ('631756721166286849',
#   {'date': '2015-08-13 09:18:34',
#    'hashtags': "['python', 'hacking']",
#    'name': 'StephanieMDavis',
#    'retweets': 0,
#    'text': 'http://t.co/0pMRxsQSob #python #hacking'}),
#  ('631669076167946240',
#   {'date': '2015-08-13 03:30:18',
#    'hashtags': "['Python', 'Azure']",
#    'name': 'Ra5tko',
#    'retweets': 26,
#    'text': "RT @VisualStudio: ...so you're having trouble debugging a #Python Web app in #Azure Web Apps? This may help: http://t.co/4CTIuRwpfL http://…"})]

# %%
# Out:
# [['kenwalger', 'kennethlove'],
#  ['groundwalkergmb', 'jeanhuguesroy'],
#  ['uogbuji', 'arh'],
#  ['j4pe_', 'eric_pommereau'],
#  ['Don_Watkins', 'rickweinberg'],
#  ['HarriSrivastav', 'algoritmic'],
#  ['HarriSrivastav', 'lonriesberg'],
#  ['ishamyyl', 'climagic'],
#  ['HarriSrivastav', 'artwisanggeni'],
#  ['HarriSrivastav', 'Proximity_ltd'],
#  ['HarriSrivastav', 'MarketACourse'],
#  ['HarriSrivastav', 'BestSQL'],
#  ['HarriSrivastav', 'ElaMoscicka'],
#  ['HarriSrivastav', 'artwisanggeni'],
#  ['HarriSrivastav', 'nodenow'],
#  ['HarriSrivastav', '_testanic'],
#  ['_organicit', 'pcgeek86'],
#  ['melindathrasher', 'djangogirls'],
#  ['ryanteck', 'MuseumsInspire'],
#  ['ryanteck', 'computermuseum'],
#  ['ryanteck', 'Raspberry_Pi'],
#  ['lgtr', 'dajool_com'],
#  ['hayza11', 'googletricks19'],
#  ['kenwalger', 'kennethlove'],
#  ['isurunix', 'nodenow'],
#  ['MikeHerman', 'pycoders'],
#  ['MikeHerman', 'Podcast__init__'],
#  ['MikeHerman', 'jessicamckellar'],
#  ['joebalalaika', 'RealPython'],
#  ['mr_brejoc', 'lgtr'],
#  ['Patty_1982', 'MuseumsInspire'],
#  ['Patty_1982', 'computermuseum'],
#  ['Patty_1982', 'Raspberry_Pi'],
#  ['Enk1Florez', 'reptiles'],
#  ['retweetjava', 'googletricks19'],
#  ['AritzSala', 'MuseumsInspire'],
#  ['AritzSala', 'computermuseum'],
#  ['AritzSala', 'Raspberry_Pi'],
#  ['CesaredePadua', 'googletricks19'],
#  ['jonDevBot', 'googletricks19'],
#  ['MadKantor', 'NoahKantor'],
#  ['MadKantor', 'MadKantor'],
#  ['groundwalkergmb', 'jeanhuguesroy'],
#  ['groundwalkergmb', 'wesmckinn'],
#  ['mistycreates', 'ernest_lara'],
#  ['mistycreates', 'talentians'],
#  ['narioINC', 'MuseumsInspire'],
#  ['narioINC', 'computermuseum'],
#  ['narioINC', 'Raspberry_Pi'],
#  ['aruprahul', 'quantifiedcode'],
#  ['AvailabilityUK', 'Availability_N'],
#  ['Python_Quest', 'dv_geek'],
#  ['Python_Quest', 'dv_geek'],
#  ['DataWookie', 'groundwalkergmb'],
#  ['DataWookie', 'jeanhuguesroy'],
#  ['DataWookie', 'wesmckinn'],
#  ['lazy_daemon', 'jms_dot_py'],
#  ['lazy_daemon', 'Smerity'],
#  ['lazy_daemon', 'CommonCrawl'],
#  ['lazy_daemon', 'bellingcat'],
#  ['hayza11', 'nodenow'],
#  ['biglesp', 'pycoders'],
#  ['cool_python', 'pycoders'],
#  ['uogbuji', 'arh'],
#  ['uogbuji', 'ndw'],
#  ['BelgiumInvestor', 'randal_olson'],
#  ['ignorantcowboy', 'pycoders'],
#  ['zeth0', 'pycoders'],
#  ['arbiterofbits', 'airpair'],
#  ['arbiterofbits', 'ryan_sb'],
#  ['arbiterofbits', 'ThePSF'],
#  ['damarsan', 'pycoders'],
#  ['chrismattmann', 'ContinuumIO'],
#  ['ShirleyYYoung', 'pycoders'],
#  ['revolunet', '_kemar'],
#  ['kevin_murdock9', 'pycoders'],
#  ['JenPhillipsK', 'ADPCareers'],
#  ['bettlebrox', 'bostonpython'],
#  ['cool_python', 'bostonpython'],
#  ['bikemule', 'PythonWeekly'],
#  ['MarkRGray', 'MuseumsInspire'],
#  ['MarkRGray', 'computermuseum'],
#  ['MarkRGray', 'Raspberry_Pi'],
#  ['JarkkoAalto', 'jms_dot_py'],
#  ['JarkkoAalto', 'Smerity'],
#  ['JarkkoAalto', 'CommonCrawl'],
#  ['JarkkoAalto', 'bellingcat'],
#  ['CowboyGamedevBt', 'Ean_Dream'],
#  ['FerroRodolfo', 'quantifiedcode'],
#  ['p2pWebMobileIt', 'p2people'],
#  ['adilkhash', 'PythonWeekly'],
#  ['umoga_bot', 'Ean_Dream'],
#  ['StephenPiment', 'wesmckinn'],
#  ['DataWookie', 'tng_konrad'],
#  ['lambdaman', 'dizballanze'],
#  ['ADPCareers', 'JenPhillipsK'],
#  ['ADPCareers', 'ADPCareers'],
#  ['VVagias', 'JenPhillipsK'],
#  ['VVagias', 'ADPCareers'],
#  ['itknowingness', 'JenPhillipsK'],
#  ['itknowingness', 'ADPCareers'],
#  ['henriquebastos', 'ramalhoorg'],
#  ['henriquebastos', 'Coverity'],
#  ['henriquebastos', 'ThePSF'],
#  ['safaribot', 'safari'],
#  ['Cyruxnet_ciber', 'SecurityTube'],
#  ['Krysten911', 'geometadata'],
#  ['Krysten911', 'GISCorps'],
#  ['Krysten911', 'URISA'],
#  ['DansLeRuSH', 'jeromebuseyne'],
#  ['cool_python', 'StephenPiment'],
#  ['eossipov', 'TheHackersNews'],
#  ['le_breaun', 'LiquesBoutique'],
#  ['le_breaun', 'le_breaun'],
#  ['hellc2', 'pycoders'],
#  ['P3Geek', 'mattcaldwell'],
#  ['py_litox', 'machinalis'],
#  ['py_litox', 'djangoproject'],
#  ['cmarslett', 'TheHackersNews'],
#  ['retweetjava', 'techy_becki'],
#  ['SzarekKrzysztof', 'pycoders'],
#  ['michiganbuilt', 'randal_olson'],
#  ['j00bar', 'ramalhoorg'],
#  ['j00bar', 'Coverity'],
#  ['j00bar', 'ThePSF'],
#  ['schep_', 'ramalhoorg'],
#  ['schep_', 'Coverity'],
#  ['schep_', 'ThePSF'],
#  ['writingcapital', 'Statistical_Est'],
#  ['Rupi_Ray', 'toptalllc'],
#  ['isurunix', 'BrawlinMelgar'],
#  ['p2pWebMobileIt', 'p2people'],
#  ['dkreuz', 'AgilesStudieren'],
#  ['rasbt', 'vmirly'],
#  ['Evild3ad79', 'jms_dot_py'],
#  ['Evild3ad79', 'Smerity'],
#  ['Evild3ad79', 'CommonCrawl'],
#  ['Evild3ad79', 'bellingcat'],
#  ['myvariantinfo', 'UW'],
#  ['CodingCampus', 'sariahmasterson'],
#  ['CodingCampus', 'ryanwi'],
#  ['CodingCampus', 'CodingCampus'],
#  ['hjpocock', 'PythonWeekly'],
#  ['hjpocock', 'haltersweb'],
#  ['MarcucciEdoardo', 'quantifiedcode'],
#  ['ameanmbot', 'py3k'],
#  ['wcmckeedotcom', 'quantifiedcode'],
#  ['ameanmbot', 'artwisanggeni'],
#  ['MartyMacGyver', 'takluyver'],
#  ['MartyMacGyver', 'sfpythonmeetup'],
#  ['P3Geek', 'MartyMacGyver'],
#  ['P3Geek', 'takluyver'],
#  ['P3Geek', 'sfpythonmeetup'],
#  ['pdr2002', 'rae_simon'],
#  ['j4pe_', 'eric_pommereau'],
#  ['j4pe_', 'hpiedcoq'],
#  ['j4pe_', 'timeml2013'],
#  ['MartyMacGyver', 'takluyver'],
#  ['P3Geek', 'MartyMacGyver'],
#  ['P3Geek', 'takluyver'],
#  ['lmgracia', 'artwisanggeni'],
#  ['raespresso', 'CA_Careers'],
#  ['javascriptd', 'nodenow'],
#  ['fancashire', 'MuseumsInspire'],
#  ['fancashire', 'computermuseum'],
#  ['fancashire', 'Raspberry_Pi'],
#  ['aakela', 'AppDynamics'],
#  ['markpnathan', 'ziparico'],
#  ['ravada_sree', 'markpnathan'],
#  ['ravada_sree', 'ziparico'],
#  ['ahseeder', 'dizballanze'],
#  ['TFConsult', 'PythonSV'],
#  ['PythonSV', 'TFConsult'],
#  ['PythonSV', 'PythonSV'],
#  ['HilmanRHCSA', 'quantifiedcode'],
#  ['horstwilmes', 'Tuxar_uk'],
#  ['horstwilmes', 'ZEEFcom'],
#  ['VeitSchiele', 'PyBerlin'],
#  ['schniggie', 'jms_dot_py'],
#  ['schniggie', 'Smerity'],
#  ['schniggie', 'CommonCrawl'],
#  ['schniggie', 'bellingcat'],
#  ['PyBerlin', 'VeitSchiele'],
#  ['PyBerlin', 'PyBerlin'],
#  ['CodementorIO', 'AndyAtUdacity'],
#  ['CodementorIO', 'udacity'],
#  ['jclassified89', 'jclassified89'],
#  ['Python_Quest', 'dv_geek'],
#  ['Python_Quest', 'dv_geek'],
#  ['StackDevJobs', 'Rackspace'],
#  ['MonsieurRaccoon', 'StackDevJobs'],
#  ['MonsieurRaccoon', 'Rackspace'],
#  ['PythonDaily', 'computermuseum'],
#  ['PythonDaily', 'Raspberry_Pi'],
#  ['JackBaldwin16', 'PythonDaily'],
#  ['JackBaldwin16', 'computermuseum'],
#  ['JackBaldwin16', 'Raspberry_Pi'],
#  ['juanjeojeda', 'pycoders'],
#  ['llevaNEUS', 'crisodisy'],
#  ['Don_Watkins', 'rickweinberg'],
#  ['rroumeliotis', 'OReillyMedia'],
#  ['martinmev', 'randal_olson'],
#  ['ageldama', 'pythontrending'],
#  ['brolettolinux', 'pythontrending'],
#  ['NoSQLDigest', 'JenPhillipsK'],
#  ['NoSQLDigest', 'ADPCareers'],
#  ['NoSQLDigest', 'JenPhillipsK'],
#  ['datacarpentry', 'LeahAWasser'],
#  ['datacarpentry', 'datacarpentry'],
#  ['BioGPS', 'myvariantinfo'],
#  ['cool_python', 'pythontrending'],
#  ['cool_python', 'pythontrending'],
#  ['MLKoooDNL', 'randal_olson'],
#  ['NoSQLDigest', 'artwisanggeni'],
#  ['NoSQLDigest', 'py3k'],
#  ['PROMO25K', 'VeitSchiele'],
#  ['PROMO25K', 'PyBerlin'],
#  ['ameanmbot', 'artwisanggeni'],
#  ['ChillRadio365', 'VeitSchiele'],
#  ['ChillRadio365', 'PyBerlin'],
#  ['NEONInc', 'LeahAWasser'],
#  ['NEONInc', 'NEONInc'],
#  ['cool_python', 'pycoders'],
#  ['globaloneexpo', 'NeuvooAdmBos'],
#  ['spaceleftblank', 'cltrudeau'],
#  ['DataWookie', 'LeahAWasser'],
#  ['Python_Quest', 'dv_geek'],
#  ['Python_Quest', 'dv_geek'],
#  ['indicoData', 'JeffreyDeFauw'],
#  ['lporcheron', 'pycoders'],
#  ['panseybard', 'Arquason'],
#  ['SPCAF', 'ITworld'],
#  ['mapopa', 'chrisemoody'],
#  ['kevikoech', 'pythontrending'],
#  ['kevikoech', 'pythontrending'],
#  ['fgmacedo', 'ramalhoorg'],
#  ['fgmacedo', 'Coverity'],
#  ['fgmacedo', 'ThePSF'],
#  ['JuanXote23', 'argenpython'],
#  ['javascriptd', 'SPCAF'],
#  ['javascriptd', 'ITworld'],
#  ['Simacoder', 'pycoders'],
#  ['cool_python', 'pycoders'],
#  ['avmoldovan', 'kdnuggets'],
#  ['felipehoffa', 'JaCooozi'],
#  ['felipehoffa', 'google'],
#  ['Ronsuez', 'RealPython'],
#  ['JvCode', 'pycoders'],
#  ['razibinrais', 'pycoders'],
#  ['BDUGUK', 'JaCooozi'],
#  ['BDUGUK', 'google'],
#  ['LoopAILabs', 'kdnuggets'],
#  ['CharlesAydin', 'kdnuggets'],
#  ['crsmithdev', 'pims'],
#  ['crsmithdev', 'martincozzi'],
#  ['isurunix', 'humerouscoder'],
#  ['ShirleyYYoung', 'pycoders'],
#  ['p2pWebMobileIt', 'p2people'],
#  ['robarte_robin', 'maximaxoo'],
#  ['robarte_robin', 'LiveScience'],
#  ['seattle113', 'pycoders'],
#  ['vikramank14', 'kdnuggets'],
#  ['JoPrimeau_', 'pycoders'],
#  ['JoPrimeau_', 'py3k'],
#  ['cool_python', 'py3k'],
#  ['Juvenal_JVC', 'kdnuggets'],
#  ['reis_pt', 'pycoders'],
#  ['code_ant', 'nodenow'],
#  ['CjoelHarrison', 'kdnuggets'],
#  ['PythonSV', 'pycologne'],
#  ['PythonSV', 'pythoncamp'],
#  ['mariuskarma', 'kdnuggets'],
#  ['p2pWebMobileIt', 'p2people'],
#  ['MarcMagn1', 'BokehPlots'],
#  ['p2pWebMobileIt', 'p2people'],
#  ['HarriSrivastav', 'algoritmic'],
#  ['HarriSrivastav', 'gutenberg_org'],
#  ['HarriSrivastav', 'ThePSF'],
#  ['joes_joy', 'saparajit'],
#  ['joes_joy', 'KirkDBorne'],
#  ['brandonh639', 'TeachTheMachine'],
#  ['brandonh639', 'EXADude'],
#  ['brandonh639', 'alexhwoods'],
#  ['adriennefriend', 'djangogirlsATL'],
#  ['TATA_BOX', 'saparajit'],
#  ['TATA_BOX', 'KirkDBorne'],
#  ['joes_joy', 'KirkDBorne'],
#  ['hackblossom', 'adriennefriend'],
#  ['hackblossom', 'djangogirlsATL'],
#  ['likeablelocal', 'likeablelocal'],
#  ['ContinuumIO', 'b_smoke'],
#  ['ContinuumIO', 'BokehPlots'],
#  ['leriomaggio', 'ContinuumIO'],
#  ['leriomaggio', 'b_smoke'],
#  ['leriomaggio', 'BokehPlots'],
#  ['rmrqj', 'raymondh'],
#  ['Python_Quest', 'dv_geek'],
#  ['Python_Quest', 'dv_geek'],
#  ['crontab', 'algoritmic'],
#  ['blackprmachine', 'likeablelocal'],
#  ['blackprmachine', 'likeablelocal'],
#  ['p2pWebMobileIt', 'p2people'],
#  ['b_smoke', 'ContinuumIO'],
#  ['b_smoke', 'b_smoke'],
#  ['b_smoke', 'BokehPlots'],
#  ['PyLadiesATL', 'pyatl'],
#  ['CableMagz', 'likeablelocal'],
#  ['CableMagz', 'likeablelocal'],
#  ['intelligence_za', 'github'],
#  ['Smerity', 'jms_dot_py'],
#  ['Smerity', 'Smerity'],
#  ['Smerity', 'CommonCrawl'],
#  ['Smerity', 'bellingcat'],
#  ['CommonCrawl', 'jms_dot_py'],
#  ['CommonCrawl', 'Smerity'],
#  ['CommonCrawl', 'CommonCrawl'],
#  ['CommonCrawl', 'bellingcat'],
#  ['influx', 'raymondh'],
#  ['RevolutionR', 'Microsoft'],
#  ['RevolutionR', 'Dataweek'],
#  ['panseybard', 'RevolutionR'],
#  ['panseybard', 'Microsoft'],
#  ['panseybard', 'Dataweek'],
#  ['BerndKullick', 'msdev_de'],
#  ['HueramoEli', 'kdnuggets'],
#  ['JvCode', 'Python_Quest'],
#  ['JvCode', 'dv_geek'],
#  ['JvCode', 'Python_Quest'],
#  ['JvCode', 'dv_geek'],
#  ['HarriSrivastav', 'lonriesberg'],
#  ['HarriSrivastav', 'ThePSF'],
#  ['cool_python', 'py3k'],
#  ['isurunix', 'knime'],
#  ['abdelbrahiti', 'H943x0'],
#  ['isurunix', 'nodenow'],
#  ['roflmaokthxbye', 'adriennefriend'],
#  ['roflmaokthxbye', 'djangogirlsATL'],
#  ['unwiredasia', '_LCK'],
#  ['pythoncamp', 'PythonSV'],
#  ['pythoncamp', 'pycologne'],
#  ['pythoncamp', 'pythoncamp'],
#  ['tomy_koch', 'PythonSV'],
#  ['tomy_koch', 'pycologne'],
#  ['tomy_koch', 'pythoncamp'],
#  ['DataWookie', 'HarriSrivastav'],
#  ['DataWookie', 'algoritmic'],
#  ['DataWookie', 'gutenberg_org'],
#  ['DataWookie', 'ThePSF'],
#  ['reptiles', 'MissLuuLuu'],
#  ['rafaelhenrique', 'ramalhoorg'],
#  ['rafaelhenrique', 'Coverity'],
#  ['rafaelhenrique', 'ThePSF'],
#  ['retweetjava', 'nodenow'],
#  ['ameanmbot', 'StackMean'],
#  ['matt_mershon', 'elevenfifty'],
#  ['oiertwo', 'pyjokes_bot'],
#  ['oiertwo', 'acpyss'],
#  ['oiertwo', 'bcigeu'],
#  ['wcmckeedotcom', 'oiertwo'],
#  ['wcmckeedotcom', 'pyjokes_bot'],
#  ['wcmckeedotcom', 'acpyss'],
#  ['wcmckeedotcom', 'bcigeu'],
#  ['isurunix', 'crystalcodegen'],
#  ['isurunix', 'nodenow'],
#  ['cha_ra_la', 'cltrudeau'],
#  ['cha_ra_la', 'kivyframework'],
#  ['DamianoMe', 'snap_hr'],
#  ['isurunix', 'TodoCoders'],
#  ['georgeisyourman', 'knime'],
#  ['hayza11', 'DevelopersDojo'],
#  ['isurunix', 'hayza11'],
#  ['isurunix', 'StackMean'],
#  ['isurunix', 'StackMean'],
#  ['isurunix', 'StackMean'],
#  ['isurunix', 'StackMean'],
#  ['isurunix', 'StackMean'],
#  ['recuweb', 'hayza11'],
#  ['ishamyyl', 'climagic'],
#  ['HarriSrivastav', 'artwisanggeni'],
#  ['HarriSrivastav', 'ThePSF'],
#  ['sempermodo', 'hayza11'],
#  ['ArjumandYounus', 'kdnuggets'],
#  ['JvCode', 'NASA'],
#  ['IgorCarron', 'rasbt'],
#  ['isurunix', 'TodoCoders'],
#  ['isurunix', 'TodoCoders'],
#  ['kntoukakis', 'kdnuggets'],
#  ['getthereie', 'dublin_startups'],
#  ['getthereie', 'getthereie'],
#  ['speedytux', 'PythonWeekly'],
#  ['TFConsult', 'PythonSV'],
#  ['TFConsult', 'pycologne'],
#  ['TFConsult', 'pythoncamp'],
#  ['kntoukakis', 'alexhwoods'],
#  ['VIPER_IoT', 'hacksterio'],
#  ['limiear', 'GERSolar'],
#  ['speedytux', 'PythonDaily'],
#  ['speedytux', 'gmarkall'],
#  ['speedytux', 'ianozsvald'],
#  ['arduinoNewsBot', 'VIPER_IoT'],
#  ['arduinoNewsBot', 'hacksterio'],
#  ['betatim', 'rasbt'],
#  ['ContinuumIO', 'dailymuse'],
#  ['ContinuumIO', 'ch_doig'],
#  ['ContinuumIO', 'koverholt'],
#  ['rogerplevy', 'OpenDataSci'],
#  ['netrusion', 'jms_dot_py'],
#  ['netrusion', 'Smerity'],
#  ['netrusion', 'CommonCrawl'],
#  ['netrusion', 'bellingcat'],
#  ['isurunix', 'StackMean'],
#  ['isurunix', 'StackMean'],
#  ['isurunix', 'StackMean'],
#  ['rogerplevy', 'kdnuggets'],
#  ['Python_Quest', 'dv_geek'],
#  ['Python_Quest', 'dv_geek'],
#  ['alorandi', 'YhatHQ'],
#  ['JvCode', 'Python_Quest'],
#  ['JvCode', 'dv_geek'],
#  ['JvCode', 'Python_Quest'],
#  ['JvCode', 'dv_geek'],
#  ['SQL_Chasm', 'KirkDBorne'],
#  ['SQL_Chasm', 'donne_martin'],
#  ['DistrictDataLab', 'DataCommunityDC'],
#  ['DistrictDataLab', 'DistrictDataLab'],
#  ['Lidy_Monteiro', 'ramalhoorg'],
#  ['Lidy_Monteiro', 'Coverity'],
#  ['Lidy_Monteiro', 'ThePSF'],
#  ['tonyojeda3', 'DataCommunityDC'],
#  ['tonyojeda3', 'DistrictDataLab'],
#  ['alhanda', 'randal_olson'],
#  ['HarriSrivastav', 'Proximity_ltd'],
#  ['HarriSrivastav', 'aaronbartell'],
#  ['HarriSrivastav', 'IBMimag'],
#  ['HarriSrivastav', 'ThePSF'],
#  ['retweetjava', 'TodoCoders'],
#  ['OsintCrew', 'theodorosc'],
#  ['yusufcapobianco', 'v_vashishta'],
#  ['brainchatbot', 'artwisanggeni'],
#  ['retweetjava', 'TodoCoders'],
#  ['isurunix', 'aningbyu'],
#  ['HarriSrivastav', 'MarketACourse'],
#  ['HarriSrivastav', 'ThePSF'],
#  ['cool_python', 'pycoders'],
#  ['aqhat', 'OpenDataSci'],
#  ['BeardOps', 'raymondh'],
#  ['darkuncle', 'raymondh'],
#  ['rvidal', 'myvariantinfo'],
#  ['jthibodeau76', 'nodenow'],
#  ['mattgratt', 'ContinuumIO'],
#  ['mattgratt', 'dailymuse'],
#  ['mattgratt', 'ch_doig'],
#  ['mattgratt', 'koverholt'],
#  ['ShirleyYYoung', 'pycoders'],
#  ['splunkdev', 'thomrs7'],
#  ['splunkdev', 'splunkdev'],
#  ['splunkdev', 'RProgLangRR'],
#  ['cesarnogCPS', 'TodoCoders'],
#  ['cesarnogCPS', 'TodoCoders'],
#  ['whiskysec', 'jms_dot_py'],
#  ['whiskysec', 'Smerity'],
#  ['whiskysec', 'CommonCrawl'],
#  ['whiskysec', 'bellingcat'],
#  ['ergunzer', 'pycoders'],
#  ['GioV666', 'mispaginasfavor'],
#  ['jsberlin', 'PythonWeekly'],
#  ['ThugMetrics', 'myvariantinfo'],
#  ['Keri_Adams', 'CTVMorningLive'],
#  ['JvCode', 'pycoders'],
#  ['pcgeek86', 'VisualStudio'],
#  ['isurunix', 'TodoCoders'],
#  ['manejandodatos', 'ContinuumIO'],
#  ['DrAndyPardoe', 'DominoDataLab'],
#  ['mopayyo', 'ContinuumIO'],
#  ['cesarnogCPS', 'TodoCoders'],
#  ['DamianoMe', 'nodenow'],
#  ['vispyproject', 'VulkanAPI'],
#  ['NoSQLDigest', 'StackMean'],
#  ['LollyParis', 'LeahAWasser'],
#  ['js_digest', 'nodenow'],
#  ['NoSQLDigest', 'artwisanggeni'],
#  ['NoSQLDigest', 'artwisanggeni'],
#  ['tangming2005', 'myvariantinfo'],
#  ['NoSQLDigest', 'StackMean'],
#  ['leplatrem', 'pycoders'],
#  ['JvCode', 'StackMean'],
#  ['JvCode', 'artwisanggeni'],
#  ['LernPython', 'Manish_Saraswt'],
#  ['LernPython', 'Manish_Saraswt'],
#  ['isurunix', 'JobsCoding'],
#  ['hayza11', 'VIPER_IoT'],
#  ['hayza11', 'hacksterio'],
#  ['benflodge', 'MuseumsInspire'],
#  ['benflodge', 'computermuseum'],
#  ['benflodge', 'Raspberry_Pi'],
#  ['PythonDaily', 'Smerity'],
#  ['PythonDaily', 'CommonCrawl'],
#  ['PythonDaily', 'bellingcat'],
#  ['ShirleyYYoung', 'LernPython'],
#  ['safaribot', 'safari'],
#  ['damiendallimore', 'thomrs7'],
#  ['damiendallimore', 'splunkdev'],
#  ['damiendallimore', 'RProgLangRR'],
#  ['LoadImpact', 'PyGotham'],
#  ['MaxCDNDeveloper', 'nylas_crew'],
#  ['AV_PowerUp', 'Daryl_Hutchings'],
#  ['fullstackpython', 'ContinuumIO'],
#  ['fullstackpython', 'b_smoke'],
#  ['fullstackpython', 'BokehPlots'],
#  ['BaranEsen21', 'seribilgicom'],
#  ['BioGPS', 'mygeneinfo'],
#  ['BioGPS', 'myvariantinfo'],
#  ['AcidRampage', 'PythonWeekly'],
#  ['AcidRampage', 'VikParuchuri'],
#  ['JvCode', 'PythonDaily'],
#  ['JvCode', 'Smerity'],
#  ['JvCode', 'CommonCrawl'],
#  ['JvCode', 'bellingcat'],
#  ['JvCode', 'ContinuumIO'],
#  ['JvCode', 'b_smoke'],
#  ['JvCode', 'BokehPlots'],
#  ['cyrillerossant', 'vispyproject'],
#  ['cyrillerossant', 'VulkanAPI'],
#  ['AcidRampage', 'PythonWeekly'],
#  ['AcidRampage', 'thedevdungeon'],
#  ['lonriesberg', 'rasbt'],
#  ['isurunix', 'BestPHP'],
#  ['icanwinifiwant', 'Keri_Adams'],
#  ['icanwinifiwant', 'CTVMorningLive'],
#  ['retweetjava', 'hayza11'],
#  ['MathematicianV', 'MathematicianV'],
#  ['isurunix', 'nodenow'],
#  ['ytechie', 'pcgeek86'],
#  ['ytechie', 'VisualStudio'],
#  ['HarriSrivastav', 'BestSQL'],
#  ['HarriSrivastav', 'knime'],
#  ['isurunix', 'HarriSrivastav'],
#  ['isurunix', 'BestSQL'],
#  ['isurunix', 'knime'],
#  ['HarriSrivastav', 'ElaMoscicka'],
#  ['HarriSrivastav', 'ThePSF'],
#  ['javascriptd', 'nodenow'],
#  ['cool_python', 'py3k'],
#  ['cameronm1', 'marklit82'],
#  ['isurunix', 'nodenow'],
#  ['jcanistrum', 'RevolutionR'],
#  ['jcanistrum', 'Microsoft'],
#  ['jcanistrum', 'Dataweek'],
#  ['HarriSrivastav', 'artwisanggeni'],
#  ['HarriSrivastav', 'ThePSF'],
#  ['cool_python', 'py3k'],
#  ['retweetjava', 'StackMean'],
#  ['AskAppDev', 'jaffri'],
#  ['pi3rre', 'tryolabs'],
#  ['Python_Quest', 'dv_geek'],
#  ['Python_Quest', 'dv_geek'],
#  ['retweetjava', 'StackMean'],
#  ['AV_PowerUp', 'fancysandwiches'],
#  ['AV_PowerUp', 'jydoHQ'],
#  ['Fredilly', 'lonriesberg'],
#  ['retweetjava', 'StackMean'],
#  ['retweetjava', 'StackMean'],
#  ['unusedPhD', 'PythonDaily'],
#  ['gh0std4ncer', 'pythontrending'],
#  ['gh0std4ncer', 'pythontrending'],
#  ['unusedPhD', 'lcheylus'],
#  ['unusedPhD', 'PythonDaily'],
#  ['rejectionking', 'jms_dot_py'],
#  ['rejectionking', 'Smerity'],
#  ['rejectionking', 'CommonCrawl'],
#  ['rejectionking', 'bellingcat'],
#  ['retweetjava', 'StackMean'],
#  ['HarriSrivastav', 'nodenow'],
#  ['HarriSrivastav', 'ThePSF'],
#  ['wcmckeedotcom', 'jallness'],
#  ['AVTweeps_', 'AV_PowerUp'],
#  ['AVTweeps_', 'fancysandwiches'],
#  ['AVTweeps_', 'jydoHQ'],
#  ['JackBaldwin16', 'AV_PowerUp'],
#  ['JackBaldwin16', 'fancysandwiches'],
#  ['JackBaldwin16', 'jydoHQ'],
#  ['ggdaniel', 'raymondh'],
#  ['ggdaniel', 'raymondh'],
#  ['unusedPhD', 'PythonDaily'],
#  ['gh0std4ncer', 'pythontrending'],
#  ['unusedPhD', 'PythonDaily'],
#  ['unusedPhD', 'TheIronYard'],
#  ['cool_python', 'raymondh'],
#  ['DataRobot', 'PythonDaily'],
#  ['DataRobot', 'gmarkall'],
#  ['DataRobot', 'ianozsvald'],
#  ['retweetjava', 'knime'],
#  ['UtilityAPI', 'hirehoosiers'],
#  ['UtilityAPI', 'UtilityAPI'],
#  ['GygliMichael', 'raymondh'],
#  ['Python_Quest', 'dv_geek'],
#  ['Python_Quest', 'dv_geek'],
#  ['retweetjava', 'TodoCoders'],
#  ['isurunix', 'TodoCoders'],
#  ['JvCode', 'Python_Quest'],
#  ['JvCode', 'dv_geek'],
#  ['JvCode', 'Python_Quest'],
#  ['JvCode', 'dv_geek'],
#  ['retweetjava', 'nodenow'],
#  ['JvCode', 'importpython'],
#  ['isurunix', 'StackMean'],
#  ['isurunix', 'StackMean'],
#  ['DamianoMe', 'nodenow'],
#  ['unusedPhD', 'PythonDaily'],
#  ['unusedPhD', 'changelog'],
#  ['_klausi_', 'kkvie'],
#  ['_klausi_', 'roguelynn'],
#  ['_Juankar_', 'MSImagineLatam'],
#  ['Jobspresso', 'careevolution'],
#  ['NetDevr', 'MsCS__'],
#  ['blegohhornline', 'pycoders'],
#  ['mindsmocking', 'pycoders'],
#  ['isurunix', 'JobsCoding'],
#  ['OSQUI_3M', 'MSImagineLatam'],
#  ['Ryan_G_Lambert', 'codility'],
#  ['Daryl_Hutchings', 'AV_PowerUp'],
#  ['Daryl_Hutchings', 'Daryl_Hutchings'],
#  ['zuxfoucault', 'rasbt'],
#  ['HarriSrivastav', '_testanic'],
#  ['HarriSrivastav', 'ThePSF'],
#  ['Ryan_G_Lambert', 'codility'],
#  ['ameanmbot', 'findmjob'],
#  ['MarcellMontier', 'jobely'],
#  ['BigDataTweetBot', 'saparajit'],
#  ['ameanmbot', 'py_nsk'],
#  ['retweetjava', 'TodoCoders'],
#  ['JvCode', 'CodementorIO'],
#  ['upendra_35', 'sudogenes'],
#  ['P3Geek', 'mattcaldwell'],
#  ['__mharrison__', 'raymondh'],
#  ['Python_Quest', 'dv_geek'],
#  ['Python_Quest', 'dv_geek'],
#  ['lennincaro', 'RedRabbit6'],
#  ['lennincaro', 'droidstarVE'],
#  ['lennincaro', 'sgi_corp'],
#  ['lennincaro', 'droidstarVE'],
#  ['RedIndieBot', 'lennincaro'],
#  ['RedIndieBot', 'RedRabbit6'],
#  ['RedIndieBot', 'droidstarVE'],
#  ['CowboyGamedevBt', 'lennincaro'],
#  ['CowboyGamedevBt', 'RedRabbit6'],
#  ['CowboyGamedevBt', 'droidstarVE'],
#  ['umoga_bot', 'lennincaro'],
#  ['umoga_bot', 'RedRabbit6'],
#  ['umoga_bot', 'droidstarVE'],
#  ['lennincaro', 'studio8Mgta'],
#  ['lennincaro', 'droidstarVE'],
#  ['JvCode', 'Python_Quest'],
#  ['JvCode', 'dv_geek'],
#  ['JvCode', 'Python_Quest'],
#  ['JvCode', 'dv_geek'],
#  ['CowboyGamedevBt', 'lennincaro'],
#  ['CowboyGamedevBt', 'sgi_corp'],
#  ['CowboyGamedevBt', 'droidstarVE'],
#  ['CowboyGamedevBt', 'lennincaro'],
#  ['CowboyGamedevBt', 'studio8Mgta'],
#  ['CowboyGamedevBt', 'droidstarVE'],
#  ['CowboyGamedevBt', 'Parodossy'],
#  ['umoga_bot', 'lennincaro'],
#  ['umoga_bot', 'sgi_corp'],
#  ['umoga_bot', 'droidstarVE'],
#  ['umoga_bot', 'lennincaro'],
#  ['umoga_bot', 'studio8Mgta'],
#  ['umoga_bot', 'droidstarVE'],
#  ['retweetjava', 'nodenow'],
#  ['learn_lang1', 'nefinjohn'],
#  ['jonDevBot', 'nefinjohn'],
#  ['EcologyRocks', 'livecodingtv'],
#  ['livecodingtv', 'EcologyRocks'],
#  ['AlvarezDomec', 'javacodegeeks'],
#  ['HeVistoCosas', 'pycoders'],
#  ['PythonDaily', 'AV_PowerUp'],
#  ['PythonDaily', 'fancysandwiches'],
#  ['PythonDaily', 'jydoHQ'],
#  ['JZA', 'coates'],
#  ['RishiChoudhary', 'MariusdeBeer'],
#  ['RishiChoudhary', 'swaroopch'],
#  ['JesusJerezM', 'pragmaticcoders'],
#  ['ShirleyYYoung', 'javacodegeeks'],
#  ['Python_Quest', 'dv_geek'],
#  ['Python_Quest', 'dv_geek'],
#  ['indiegamesdevel', 'Bensonix'],
#  ['CowboyGamedevBt', 'Bensonix'],
#  ['umoga_bot', 'Bensonix'],
#  ['p2pWebMobileIt', 'p2people'],
#  ['onemonthedu', 'excid3'],
#  ['_organicit', 'pcgeek86'],
#  ['juanito_valle', 'sushraju'],
#  ['thinkjson', 'coates'],
#  ['winklhawk', 'SecurityTube'],
#  ['gnuyoga', 'vyoma_media'],
#  ['nucAmbiguous', 'ToferC'],
#  ['cool_python', 'py3k'],
#  ['cool_python', 'py3k'],
#  ['dunabit', 'MikeTamir'],
#  ['cliffbaldridge', 'ZEFRinc'],
#  ['cliffbaldridge', 'lesaevans'],
#  ['retweetjava', 'nodenow'],
#  ['isurunix', 'antoniovelardo_'],
#  ['shakamunyi', 'Tkalimi'],
#  ['BigDataTweetBot', 'antoniovelardo_'],
#  ['JvCode', 'PythonWeekly'],
#  ['rahulgchaudhary', 'PythonWeekly'],
#  ['melindathrasher', 'djangogirls'],
#  ['melindathrasher', 'PyLadiesSEA'],
#  ['isurunix', 'garywiz'],
#  ['Python_Quest', 'dv_geek'],
#  ['Python_Quest', 'dv_geek'],
#  ['nkhalasi', 'YhatHQ'],
#  ['JvCode', 'SecurityTube'],
#  ['DawlaMan1', 'javacodegeeks'],
#  ['JvCode', 'Python_Quest'],
#  ['JvCode', 'dv_geek'],
#  ['JvCode', 'Python_Quest'],
#  ['JvCode', 'dv_geek'],
#  ['JvCode', 'pythontrending'],
#  ['JvCode', 'Python_Quest'],
#  ['JvCode', 'dv_geek'],
#  ['JvCode', 'Python_Quest'],
#  ['JvCode', 'dv_geek'],
#  ['JvCode', 'CodeNewbies'],
#  ['cool_python', 'pythontrending'],
#  ['GalaxESolutions', 'LenaertsDaan'],
#  ['MarcMagn1', 'joeahand'],
#  ['MarcMagn1', 'getpelican'],
#  ['MarcMagn1', 'googledocs'],
#  ['MarcMagn1', 'iftt'],
#  ['CKPYT', 'vmirly'],
#  ['Utah_Dave', 'coates']]

# %%
# Out:
# [('funKidsSTEM', 'atcsapp'),
#  ('BobBodily', 'PlaceILive'),
#  ('BobBodily', 'LoralynTaylor'),
#  ('BobBodily', 'sepirdata'),
#  ('pdr2002', 'rae_simon'),
#  ('robbyki', 'Hancock_JohnD'),
#  ('Jordanmlima', 'randal_olson'),
#  ('emilyhwilson', 'fredmcconnell'),
#  ('emilyhwilson', 'OrbitalMechs'),
#  ('cmarschner', 'randal_olson'),
#  ('BitterMoa', 'moaimx'),
#  ('BitterMoa', 'GIRE_mx'),
#  ('BitterMoa', 'Data4mx'),
#  ('Niels_Bremen', 'flowingdata'),
#  ('Niels_Bremen', 'randal_olson'),
#  ('GoClickSpree', 'gregmancel'),
#  ('GoClickSpree', 'DataScienceCtrl'),
#  ('jknowles', 'HollyLynnMck'),
#  ('jknowles', 'Biff_Bruise'),
#  ('jknowles', 'EamonCaddigan'),
#  ('jknowles', 'sweetspot'),
#  ('matlabulous', 'NatGeo'),
#  ('matlabulous', 'visualisingdata'),
#  ('matlabulous', 'NadiehBremer'),
#  ('santoshosu', 'DecisionViz'),
#  ('santoshosu', 'alteryx'),
#  ('BioMickWatson', 'randal_olson'),
#  ('MAGISTR_OM', 'SkytreeHQ'),
#  ('MAGISTR_OM', 'KirkDBorne'),
#  ('GerryWieder', 'vjo'),
#  ('luzumuyok', 'Ronald_vanLoon'),
#  ('yayayarndiva', 'bayreporta'),
#  ('yayayarndiva', 'aboutaaron'),
#  ('umoga_bot', 'studio8Mgta'),
#  ('umoga_bot', 'lennincaro'),
#  ('umoga_bot', 'Ean_Dream'),
#  ('umoga_bot', 'Bensonix'),
#  ('umoga_bot', 'RedRabbit6'),
#  ('umoga_bot', 'sgi_corp'),
#  ('umoga_bot', 'droidstarVE'),
#  ('smoothyshakers', 'SustDev'),
#  ('JHannikainen', 'EU_Eurostat'),
#  ('NetDevr', 'MsCS__'),
#  ('Landa23', 'moaimx'),
#  ('Landa23', 'GIRE_mx'),
#  ('Landa23', 'Data4mx'),
#  ('Mortallywoundad', 'randal_olson'),
#  ('meg_serc', 'statsforbios'),
#  ('meg_serc', 'randal_olson'),
#  ('BlessedAtWorld', 'Visually'),
#  ('BlessedAtWorld', '517design'),
#  ('NewTechScience', 'randal_olson'),
#  ('panseybard', 'Arquason'),
#  ('panseybard', 'Microsoft'),
#  ('panseybard', 'Dataweek'),
#  ('panseybard', 'RevolutionR'),
#  ('scholarlykitchn', 'outsellinc'),
#  ('scholarlykitchn', 'robeirne'),
#  ('Ketalret', 'gregmancel'),
#  ('Ketalret', 'SM_Experts_'),
#  ('Ketalret', 'DataScienceCtrl'),
#  ('Ketalret', '_jcbales'),
#  ('Ketalret', 'mashsocialmedia'),
#  ('LoadImpact', 'PyGotham'),
#  ('AnnieMachon', 'alice_corona'),
#  ('RyanDavidReece', 'DataIsBeautiful'),
#  ('BigDataTweetBot', 'don4luv001'),
#  ('BigDataTweetBot', 'DecisionViz'),
#  ('BigDataTweetBot', 'Van_InstituteVA'),
#  ('BigDataTweetBot', 'favData'),
#  ('BigDataTweetBot', 'randal_olson'),
#  ('BigDataTweetBot', 'Sprint_Media'),
#  ('BigDataTweetBot', 'djsammy8'),
#  ('BigDataTweetBot', 'Dawnie7663'),
#  ('BigDataTweetBot', 'bayreporta'),
#  ('BigDataTweetBot', 'VisualErnesto'),
#  ('BigDataTweetBot', 'MicoYuk'),
#  ('BigDataTweetBot', 'alteryx'),
#  ('BigDataTweetBot', 'DataScienceCtrl'),
#  ('BigDataTweetBot', 'EvanSinar'),
#  ('BigDataTweetBot', 'ipredictus'),
#  ('BigDataTweetBot', 'aidotech'),
#  ('BigDataTweetBot', 'akwyz'),
#  ('BigDataTweetBot', 'BIBrainz'),
#  ('BigDataTweetBot', 'saparajit'),
#  ('BigDataTweetBot', 'analyticsonfire'),
#  ('BigDataTweetBot', 'rmgoodm'),
#  ('BigDataTweetBot', 'antoniovelardo_'),
#  ('BigDataTweetBot', 'aboutaaron'),
#  ('BigDataTweetBot', 'PlaceILive'),
#  ('BigDataTweetBot', 'twitt_doctor'),
#  ('BigDataTweetBot', 'ReportPlusApp'),
#  ('izharv2dot0', 'PlaceILive'),
#  ('izharv2dot0', 'randal_olson'),
#  ('jonDevBot', 'googletricks19'),
#  ('jonDevBot', 'nefinjohn'),
#  ('toni_fontana', 'gregmancel'),
#  ('toni_fontana', 'DataScienceCtrl'),
#  ('Toriwilliams90', 'randal_olson'),
#  ('DataWookie', 'BernardMarr'),
#  ('DataWookie', 'trebor'),
#  ('DataWookie', 'RichardACarter2'),
#  ('DataWookie', 'KASMediaAsia'),
#  ('DataWookie', 'humeursdevictor'),
#  ('DataWookie', 'timoelliott'),
#  ('DataWookie', 'AlexCEngler'),
#  ('DataWookie', 'sepirdata'),
#  ('DataWookie', 'Manuela_Stocco'),
#  ('DataWookie', 'atcsapp'),
#  ('DataWookie', 'CMBInfo'),
#  ('DataWookie', 'algoritmic'),
#  ('DataWookie', 'SASRetail'),
#  ('DataWookie', 'Elevate_Energy'),
#  ('DataWookie', 'gluu_io'),
#  ('DataWookie', 'melindagates'),
#  ('DataWookie', 'RProgLangRR'),
#  ('DataWookie', 'EasyAnalytics1'),
#  ('DataWookie', 'we_do_data'),
#  ('DataWookie', 'weckerson'),
#  ('DataWookie', 'soadaptive'),
#  ('DataWookie', 'RoxNL'),
#  ('DataWookie', 'printhuman'),
#  ('DataWookie', 'Ronald_vanLoon'),
#  ('DataWookie', 'gatesfoundation'),
#  ('DataWookie', 'Data4mx'),
#  ('DataWookie', 'PulseLabKampala'),
#  ('DataWookie', 'irregularbi'),
#  ('DataWookie', 'medhistimage'),
#  ('DataWookie', 'NadiehBremer'),
#  ('DataWookie', 'daniellynds'),
#  ('DataWookie', 'reddit'),
#  ('DataWookie', 'kenkauppila'),
#  ('DataWookie', 'dataandme'),
#  ('DataWookie', 'DataIsBeautiful'),
#  ('DataWookie', 'statsforbios'),
#  ('DataWookie', 'irinnews'),
#  ('DataWookie', 'aboutaaron'),
#  ('DataWookie', 'MinofHealthUG'),
#  ('DataWookie', '_jcbales'),
#  ('DataWookie', 'antoniovelardo_'),
#  ('DataWookie', 'WHSummit'),
#  ('DataWookie', 'EU_Eurostat'),
#  ('DataWookie', 'stephen_wolfram'),
#  ('DataWookie', 'flowingdata'),
#  ('DataWookie', 'h0neyspider'),
#  ('DataWookie', 'VisualCap'),
#  ('DataWookie', 'gregmancel'),
#  ('DataWookie', 'MaxCRoser'),
#  ('DataWookie', 'DEAGiles'),
#  ('DataWookie', 'jposamen'),
#  ('DataWookie', 'nytimes'),
#  ('DataWookie', 'ipredictus'),
#  ('DataWookie', 'qlik'),
#  ('DataWookie', 'CRPE_UW'),
#  ('DataWookie', 'NatanMeekers'),
#  ('DataWookie', 'HansRosling'),
#  ('DataWookie', 'arthurSlee'),
#  ('DataWookie', 'sperosck'),
#  ('DataWookie', 'accuratstudio'),
#  ('DataWookie', 'Niels_Bremen'),
#  ('DataWookie', 'groundwalkergmb'),
#  ('DataWookie', 'IITDesign'),
#  ('DataWookie', 'ijanric'),
#  ('DataWookie', 'tableau'),
#  ('DataWookie', 'EvanSinar'),
#  ('DataWookie', 'LeapMotion'),
#  ('DataWookie', 'research_innova'),
#  ('DataWookie', 'ciradar'),
#  ('DataWookie', 'washingtonpost'),
#  ('DataWookie', 'mohsin'),
#  ('DataWookie', 'LeahAWasser'),
#  ('DataWookie', 'Venustucad'),
#  ('DataWookie', 'ja_serra'),
#  ('DataWookie', 'CijIndia'),
#  ('DataWookie', 'BRamKram'),
#  ('DataWookie', 'AriLamstein'),
#  ('DataWookie', 'splunkdev'),
#  ('DataWookie', 'PhMai'),
#  ('DataWookie', 'BIBrainz'),
#  ('DataWookie', 'vishalchomal'),
#  ('DataWookie', 'Netlytic'),
#  ('DataWookie', 'moaimx'),
#  ('DataWookie', 'Demografia_CSIC'),
#  ('DataWookie', 'MicoYuk'),
#  ('DataWookie', 'twitt_doctor'),
#  ('DataWookie', 'randal_olson'),
#  ('DataWookie', 'who_ug'),
#  ('DataWookie', 'GIRE_mx'),
#  ('DataWookie', 'nlm_news'),
#  ('DataWookie', 'rav_aliahmad'),
#  ('DataWookie', 'brian_booden'),
#  ('DataWookie', 'KirkDBorne'),
#  ('DataWookie', 'AntoViral'),
#  ('DataWookie', 'athomas74'),
#  ('DataWookie', 'bmkiii'),
#  ('DataWookie', 'StormTelematics'),
#  ('DataWookie', 'BdeTenley'),
#  ('DataWookie', 'EdwardTufte'),
#  ('DataWookie', 'saj_asia'),
#  ('DataWookie', 'SkytreeHQ'),
#  ('DataWookie', 'Katie_3D_bio'),
#  ('DataWookie', 'gijn'),
#  ('DataWookie', 'djsammy8'),
#  ('DataWookie', 'tng_konrad'),
#  ('DataWookie', 'alice_corona'),
#  ('DataWookie', 'jeanhuguesroy'),
#  ('DataWookie', 'robertoglezcano'),
#  ('DataWookie', 'NatGeo'),
#  ('DataWookie', 'visualisingdata'),
#  ('DataWookie', 'Ognyanova'),
#  ('DataWookie', 'Visually'),
#  ('DataWookie', 'albertocairo'),
#  ('DataWookie', 'EstelleWalt'),
#  ('DataWookie', 'SilkDotCo'),
#  ('DataWookie', 'jenstirrup'),
#  ('DataWookie', 'tkb'),
#  ('DataWookie', 'haddadme'),
#  ('DataWookie', 'bryankramer'),
#  ('DataWookie', 'gutenberg_org'),
#  ('DataWookie', 'ATALLC'),
#  ('DataWookie', 'SASCanada'),
#  ('DataWookie', '365datafr'),
#  ('DataWookie', 'scoopit'),
#  ('DataWookie', 'MailOnline'),
#  ('DataWookie', 'haddame'),
#  ('DataWookie', 'wesmckinn'),
#  ('DataWookie', 'SM_Experts_'),
#  ('DataWookie', 'dreich'),
#  ('DataWookie', 'DataScienceCtrl'),
#  ('DataWookie', 'ISENatNU'),
#  ('DataWookie', 'WorldWilderLab'),
#  ('DataWookie', 'ThePSF'),
#  ('DataWookie', 'thomasforth'),
#  ('DataWookie', 'HarriSrivastav'),
#  ('DataWookie', 'robertstats'),
#  ('DataWookie', 'VizWorld'),
#  ('DataWookie', 'WSJ'),
#  ('DataWookie', 'acotgreave'),
#  ('DataWookie', 'SQLJason'),
#  ('DataWookie', 'infotools'),
#  ('DataWookie', 'rights_info'),
#  ('DataWookie', 'BuzzFeed'),
#  ('DataWookie', 'SonyGomes'),
#  ('DataWookie', 'bayreporta'),
#  ('DataWookie', 'charlesmeaden'),
#  ('DataWookie', 'thomrs7'),
#  ('DataWookie', 'PlaceILive'),
#  ('DataWookie', 'Sophedges'),
#  ('DataWookie', 'mashsocialmedia'),
#  ('CaptainDoone', 'HacksHackers'),
#  ('CaptainDoone', 'robertstats'),
#  ('CaptainDoone', 'DataScienceCtrl'),
#  ('CaptainDoone', 'gregmancel'),
#  ('CaptainDoone', 'SASanalytics'),
#  ('CaptainDoone', 'GemmaSPearce'),
#  ('CaptainDoone', 'jase_thomas'),
#  ('Lisi_Nick', 'MapleLeafs'),
#  ('ChristyMJacob', 'Visually'),
#  ('ChristyMJacob', '517design'),
#  ('SzarekKrzysztof', 'pycoders'),
#  ('KenningtonPOB', 'BriceDev'),
#  ('MartinGaedt', 'Ronald_vanLoon'),
#  ('arbiterofbits', 'airpair'),
#  ('arbiterofbits', 'ThePSF'),
#  ('arbiterofbits', 'ryan_sb'),
#  ('real_ashther', 'joshsmithnyc'),
#  ('real_ashther', 'HollyNielsen'),
#  ('real_ashther', 'jsteeleeditor'),
#  ('real_ashther', 'EdwardTufte'),
#  ('real_ashther', 'blprnt'),
#  ('rachellynnec', 'storywithdata'),
#  ('mopayyo', 'ContinuumIO'),
#  ('rOpenSci', 'albertocairo'),
#  ('rOpenSci', 'rights_info'),
#  ('rOpenSci', 'TB_Times'),
#  ('rOpenSci', 'Nat_Lash'),
#  ('mihirzaveri', 'bayreporta'),
#  ('mihirzaveri', 'aboutaaron'),
#  ('Ryan_G_Lambert', 'codility'),
#  ('offrayLC', 'agaviriau'),
#  ('offrayLC', 'MinSaludCol'),
#  ('USEReadyInc', 'doctormeisje'),
#  ('MCoteDigital', 'Rbloggers'),
#  ('MCoteDigital', 'Creatuluw'),
#  ('yasserglez', 'albertocairo'),
#  ('RionMotley', 'DataIsBeautiful'),
#  ('EstelleWalt', 'EstelleWalt'),
#  ('EstelleWalt', 'humeursdevictor'),
#  ('joe_thorley', 'randal_olson'),
#  ('HTML5Sit_es', 'AnyChart'),
#  ('SiddharthRoy', 'nytimes'),
#  ('double_thunk', 'randal_olson'),
#  ('Trustnet_Daniel', 'randal_olson'),
#  ('henrikbengtsson', 'Dawnie7663'),
#  ('henrikbengtsson', 'ipredictus'),
#  ('KusturieM', 'EvanSinar'),
#  ('Cellular_PP', 'rights_info'),
#  ('lazy_daemon', 'CommonCrawl'),
#  ('lazy_daemon', 'bellingcat'),
#  ('lazy_daemon', 'Smerity'),
#  ('lazy_daemon', 'jms_dot_py'),
#  ('cmarslett', 'TheHackersNews'),
#  ('liberrenaud', 'HollyLynnMck'),
#  ('liberrenaud', 'sweetspot'),
#  ('shawnmjones', 'DataIsBeautiful'),
#  ('deaneckles', 'Venustucad'),
#  ('deaneckles', 'research_innova'),
#  ('deaneckles', 'jenstirrup'),
#  ('deaneckles', 'robertoglezcano'),
#  ('juanjeojeda', 'pycoders'),
#  ('lindabird65', 'randal_olson'),
#  ('wgi_la11ur', 'rights_info'),
#  ('ArjumandYounus', 'kdnuggets'),
#  ('astrobob_tk', 'PlaceILive'),
#  ('PhD_Connect', 'AntoViral'),
#  ('tasneemraja', 'bayreporta'),
#  ('tasneemraja', 'aboutaaron'),
#  ('CjoelHarrison', 'kdnuggets'),
#  ('peacockc', 'randal_olson'),
#  ('s_neyshabouri', 'randal_olson'),
#  ('felipehoffa', 'google'),
#  ('felipehoffa', 'JaCooozi'),
#  ('AlexBukengolz', 'SilkDotCo'),
#  ('eimearfarrell', 'WHSummit'),
#  ('eimearfarrell', 'UNDP'),
#  ('vinuct', 'randal_olson'),
#  ('cherryhihi', 'ClimateDesk'),
#  ('cherryhihi', 'MaliciaRogue'),
#  ('brycelegal', 'EvanSinar'),
#  ('AntoineTweeting', 'Bahareh360'),
#  ('AntoineTweeting', 'Creatuluw'),
#  ('pi3rre', 'tryolabs'),
#  ('llevaNEUS', 'crisodisy'),
#  ('rdemes', 'randal_olson'),
#  ('RaviNepal', 'tkb'),
#  ('VisualErnesto', 'DataScienceCtrl'),
#  ('oiertwo', 'pyjokes_bot'),
#  ('oiertwo', 'acpyss'),
#  ('oiertwo', 'bcigeu'),
#  ('NatanMeekers', 'flowingdata'),
#  ('_klausi_', 'kkvie'),
#  ('_klausi_', 'roguelynn'),
#  ('BeardOps', 'raymondh'),
#  ('luis_zeni', 'babgi'),
#  ('e_riviere1', '365datafr'),
#  ('e_riviere1', 'we_do_data'),
#  ('CKPYT', 'vmirly'),
#  ('moneywithwings', 'reddit'),
#  ('MaxCDNDeveloper', 'nylas_crew'),
#  ('AngusNeilson1', 'Ronald_vanLoon'),
#  ('Mumkaya', 'randal_olson'),
#  ('FrankBedoyaM', 'randal_olson'),
#  ('danailon', 'SustDev'),
#  ('nucAmbiguous', 'ToferC'),
#  ('usdatagov', 'DataCommunityDC'),
#  ('usdatagov', 'usdatagov'),
#  ('usdatagov', 'usedgov'),
#  ('discretestates', 'Ronald_vanLoon'),
#  ('crazytiredmommy', 'randal_olson'),
#  ('RevolutionR', 'Microsoft'),
#  ('RevolutionR', 'Dataweek'),
#  ('abbysname', 'DataIsBeautiful'),
#  ('iramjohn', 'randal_olson'),
#  ('GordonBrianR', 'randal_olson'),
#  ('dabogda', 'robroc'),
#  ('dabogda', 'jeanhuguesroy'),
#  ('dabogda', 'NaelShiab'),
#  ('dabogda', 'fdaudens'),
#  ('kara_woo', 'Ronald_vanLoon'),
#  ('kara_woo', 'kara_woo'),
#  ('henriquebastos', 'ThePSF'),
#  ('henriquebastos', 'ramalhoorg'),
#  ('henriquebastos', 'Coverity'),
#  ('mtdsousa', 'randal_olson'),
#  ('aakela', 'AppDynamics'),
#  ('FreiheitExpert', 'rights_info'),
#  ('WilfDinnick', 'mohsin'),
#  ('WilfDinnick', 'haddadme'),
#  ('trisetyarso', 'DataIsBeautiful'),
#  ('vbd', 'EU_Eurostat'),
#  ('vbd', 'randal_olson'),
#  ('statscience_cl', 'kaggle'),
#  ('statscience_cl', 'DataRobot'),
#  ('statscience_cl', 'KirkDBorne'),
#  ('statscience_cl', 'citycalfe'),
#  ('statscience_cl', 'MathiasLeroy_'),
#  ('SimonMoritz', 'fitbit'),
#  ('SimonMoritz', 'randal_olson'),
#  ('VeloCharts', 'BriceDev'),
#  ('FerroRodolfo', 'quantifiedcode'),
#  ('teioh', 'randal_olson'),
#  ('convexpolytop', 'SilkDotCo'),
#  ('gh0std4ncer', 'pythontrending'),
#  ('OsintCrew', 'theodorosc'),
#  ('ainvienna', 'randal_olson'),
#  ('OberoiPri', 'AnyChart'),
#  ('DDSecBlog', 'GoogleTrends'),
#  ('ergunzer', 'pycoders'),
#  ('kwbroman', 'timelyportfolio'),
#  ('dasaptaerwin', 'citedeleconomie'),
#  ('dasaptaerwin', 'Banquemondiale'),
#  ('dasaptaerwin', 'AlexCEngler'),
#  ('unwiredasia', '_LCK'),
#  ('YwanVanLoon', 'Ronald_vanLoon'),
#  ('abresler', 'nicknyhan'),
#  ('morioka', 'UNESCO'),
#  ('KristinHenry', 'bayreporta'),
#  ('KristinHenry', 'aboutaaron'),
#  ('GueyeNono', 'randal_olson'),
#  ('LizzWaring', 'statsforbios'),
#  ('LizzWaring', 'OptimiseOrDie'),
#  ('habhit', 'citedeleconomie'),
#  ('habhit', 'SciencePresse'),
#  ('markpetersjr', 'nocashvalue80'),
#  ('evanpdunn', 'nicknyhan'),
#  ('evanpdunn', 'DataScienceCtrl'),
#  ('evanpdunn', 'vishalchomal'),
#  ('poonia_mukul', 'dumpark'),
#  ('cehc84', 'randal_olson'),
#  ('rapidprototypin', 'Katie_3D_bio'),
#  ('rapidprototypin', 'printhuman'),
#  ('martinmev', 'randal_olson'),
#  ('PyBerlin', 'PyBerlin'),
#  ('PyBerlin', 'VeitSchiele'),
#  ('RLangTip', 'albertocairo'),
#  ('RLangTip', 'Ronald_vanLoon'),
#  ('leplatrem', 'pycoders'),
#  ('USEmbassyFrance', '365datafr'),
#  ('USEmbassyFrance', 'we_do_data'),
#  ('ChrisBeeley', 'doctormeisje'),
#  ('tangming2005', 'myvariantinfo'),
#  ('tangming2005', 'gatesfoundation'),
#  ('antoniovelardo_', 'PlaceILive'),
#  ('vbucs', 'mauriciomacri'),
#  ('vbucs', 'DelaSotaOk'),
#  ('statsforbios', 'TimBrock_DtD'),
#  ('DoodlingData', 'randal_olson'),
#  ('BarryLMacDonald', 'fredmcconnell'),
#  ('BarryLMacDonald', 'OrbitalMechs'),
#  ('HeVistoCosas', 'pycoders'),
#  ('LouiseGuionie', '365datafr'),
#  ('LouiseGuionie', 'we_do_data'),
#  ('avmoldovan', 'kdnuggets'),
#  ('sempermodo', 'hayza11'),
#  ('LostProphet77', 'randal_olson'),
#  ('romunov', 'rights_info'),
#  ('inesgn', 'atcsapp'),
#  ('GalaxESolutions', 'LenaertsDaan'),
#  ('EndeavourSci', 'randal_olson'),
#  ('natorro', 'NAHBhome'),
#  ('biglesp', 'pycoders'),
#  ('mindsmocking', 'pycoders'),
#  ('RProgramming', 'randal_olson'),
#  ('paldhous', 'albertocairo'),
#  ('fverter', 'randal_olson'),
#  ('UtilityAPI', 'UtilityAPI'),
#  ('UtilityAPI', 'hirehoosiers'),
#  ('MadKantor', 'NoahKantor'),
#  ('MadKantor', 'MadKantor'),
#  ('Inomla', '517design'),
#  ('keeeeei0315', 'MicoYuk'),
#  ('keeeeei0315', 'analyticsonfire'),
#  ('keeeeei0315', 'rmgoodm'),
#  ('DrEFHwrites', 'randal_olson'),
#  ('iTonySandhu', 'MyNarmis'),
#  ('nbarrowman', 'thomasforth'),
#  ('nbarrowman', 'robertstats'),
#  ('intelligence_za', 'github'),
#  ('P3Geek', 'takluyver'),
#  ('P3Geek', 'mattcaldwell'),
#  ('P3Geek', 'sfpythonmeetup'),
#  ('P3Geek', 'MartyMacGyver'),
#  ('MaksNikol', 'bryankramer'),
#  ('adriennefriend', 'djangogirlsATL'),
#  ('chndlrrj', 'randal_olson'),
#  ('UNDPEurasia', 'irinnews'),
#  ('analytdata', 'KLirenman'),
#  ('analytdata', 'ceeshameete'),
#  ('analytdata', 'FrankDormont'),
#  ('giocante', 'BIBrainz'),
#  ('giocante', 'MicoYuk'),
#  ('alpaslankbulut', 'Demografia_CSIC'),
#  ('alpaslankbulut', 'randal_olson'),
#  ('hey_anmol', 'TechCrunch'),
#  ('HacksHackers', 'HacksHackers'),
#  ('HacksHackers', 'jase_thomas'),
#  ('f_fusterfabra', 'Europe_'),
#  ('f_fusterfabra', 'rights_info'),
#  ('DataAndDataViz', 'NatGeo'),
#  ('DataAndDataViz', 'tableau'),
#  ('DataAndDataViz', 'NadiehBremer'),
#  ('DataAndDataViz', 'aboutaaron'),
#  ('DataAndDataViz', 'Mazhun'),
#  ('DataAndDataViz', 'visualisingdata'),
#  ('DataAndDataViz', 'randal_olson'),
#  ('DataAndDataViz', 'KirkDBorne'),
#  ('DataAndDataViz', 'bayreporta'),
#  ('PHInformatics', 'nocashvalue80'),
#  ('lgtr', 'dajool_com'),
#  ('MathematicianV', 'MathematicianV'),
#  ('earlconf', 'Forbes'),
#  ('earlconf', 'dorieclark'),
#  ('earlconf', 'philsimon'),
#  ('alhanda', 'randal_olson'),
#  ('obrienchr', 'randal_olson'),
#  ('Dawnie7663', 'ipredictus'),
#  ('UNLibrary', 'WHSummit'),
#  ('militantDLF', '365datafr'),
#  ('militantDLF', 'we_do_data'),
#  ('Harleanlook', 'randal_olson'),
#  ('onemonthedu', 'excid3'),
#  ('DataScie', 'DataIsBeautiful'),
#  ('blindingobvious', 'alice_corona'),
#  ('datstory', 'visualisingdata'),
#  ('datstory', 'PlaceILive'),
#  ('datstory', 'SilkDotCo'),
#  ('datstory', 'ciradar'),
#  ('datstory', 'etabsnews'),
#  ('pekkasauri', 'EU_Eurostat'),
#  ('PsephoAnalytics', 'fredmcconnell'),
#  ('PsephoAnalytics', 'OrbitalMechs'),
#  ('NEONInc', 'NEONInc'),
#  ('NEONInc', 'LeahAWasser'),
#  ('hilary_dotson', 'randal_olson'),
#  ('KnollDaniela', 'albertocairo'),
#  ('KnollDaniela', 'flowingdata'),
#  ('RichardACarter2', 'albertocairo'),
#  ('RichardACarter2', 'kimgrinfeder'),
#  ('iezha26', 'la_stampa'),
#  ('kevin_ushey', 'SASRetail'),
#  ('sepirdata', 'PlaceILive'),
#  ('sepirdata', 'SputnikInt'),
#  ('HomesAtMetacoda', 'SASanalytics'),
#  ('HomesAtMetacoda', 'flowingdata'),
#  ('HomesAtMetacoda', 'SASsoftware'),
#  ('AppliedML', 'DataRobot'),
#  ('Oacnudh_GT', 'WHSummit'),
#  ('wcmckeedotcom', 'oiertwo'),
#  ('wcmckeedotcom', 'pyjokes_bot'),
#  ('wcmckeedotcom', 'bcigeu'),
#  ('wcmckeedotcom', 'quantifiedcode'),
#  ('wcmckeedotcom', 'acpyss'),
#  ('wcmckeedotcom', 'jallness'),
#  ('alexissarat', 'weckerson'),
#  ('alexissarat', 'AnitaGibbings'),
#  ('EdKwedar', 'SkytreeHQ'),
#  ('EdKwedar', 'KirkDBorne'),
#  ('mglbrjs', 'akwyz'),
#  ('_FutureFresh', 'albertocairo'),
#  ('_FutureFresh', 'kimgrinfeder'),
#  ('myvariantinfo', 'UW'),
#  ('govindsyadav', 'albertocairo'),
#  ('TATA_BOX', 'KirkDBorne'),
#  ('TATA_BOX', 'saparajit'),
#  ('learn_lang1', 'nefinjohn'),
#  ('Melissa6revs', 'gregmancel'),
#  ('Melissa6revs', 'DataScienceCtrl'),
#  ('JenkinBeattie', 'adamwoodsaus'),
#  ('dinisguarda', 'worldbankdata'),
#  ('LeahAWasser', 'mikescharff'),
#  ('LeahAWasser', 'WHSummit'),
#  ('LeahAWasser', 'DataIsBeautiful'),
#  ('MetaLSolter', 'randal_olson'),
#  ('MarkRGray', 'MuseumsInspire'),
#  ('MarkRGray', 'Raspberry_Pi'),
#  ('MarkRGray', 'computermuseum'),
#  ('tmnc', 'randal_olson'),
#  ('mdjoner', 'randal_olson'),
#  ('predixn', 'Ronald_vanLoon'),
#  ('marcinkula', 'EU_Eurostat'),
#  ('marknca', 'Van_InstituteVA'),
#  ('marknca', 'MailOnline'),
#  ('Innovate4ever', 'babgi'),
#  ('5h15h', 'marcreguera'),
#  ('5h15h', 'BlueGraniteInc'),
#  ('HilmanRHCSA', 'quantifiedcode'),
#  ('CoreySparks1', 'randal_olson'),
#  ('fabienevrard', '365datafr'),
#  ('fabienevrard', 'we_do_data'),
#  ('NancyScience', 'JuiceAnalytics'),
#  ('NancyScience', 'NancyScience'),
#  ('NancyScience', 'statsforbios'),
#  ('vlandham', 'bayreporta'),
#  ('vlandham', 'aboutaaron'),
#  ('ishamyyl', 'climagic'),
#  ('daviddefelipe', 'gregmancel'),
#  ('daviddefelipe', 'DataScienceCtrl'),
#  ('ywsanchez', 'SkytreeHQ'),
#  ('ywsanchez', 'KirkDBorne'),
#  ('Slalom', 'Vizoftheday'),
#  ('Slalom', 'pgilks'),
#  ('resilvajr', 'artgeeky'),
#  ('bbgatch', 'randal_olson'),
#  ('anthonycosgrave', 'randal_olson'),
#  ('dataproblems', 'ReportPlusApp'),
#  ('DBiUK', 'randal_olson'),
#  ('ravada_sree', 'markpnathan'),
#  ('ravada_sree', 'ziparico'),
#  ('nicoleradziwill', 'Europe_'),
#  ('nicoleradziwill', 'f_fusterfabra'),
#  ('nicoleradziwill', 'rights_info'),
#  ('nicoleradziwill', 'randal_olson'),
#  ('metacode', 'joshsmithnyc'),
#  ('metacode', 'HollyNielsen'),
#  ('metacode', 'jsteeleeditor'),
#  ('metacode', 'EdwardTufte'),
#  ('metacode', 'blprnt'),
#  ('sgoetinck', 'Hancock_JohnD'),
#  ('DrExplain', 'Ronald_vanLoon'),
#  ('segalop', 'SilkDotCo'),
#  ('AlexPawlowski_', 'randal_olson'),
#  ('hadleywickham', 'EvanSinar'),
#  ('hadleywickham', 'lonriesberg'),
#  ('algoritmic', 'business'),
#  ('algoritmic', 'BlackiLi'),
#  ('algoritmic', 'eroston'),
#  ('aqhat', 'dataMares'),
#  ('aqhat', 'OpenDataSci'),
#  ('aqhat', 'randal_olson'),
#  ('PROMO25K', 'PyBerlin'),
#  ('PROMO25K', 'artgeeky'),
#  ('PROMO25K', 'VeitSchiele'),
#  ('CarlosPaezAgraz', 'dataMares'),
#  ('CarlosPaezAgraz', 'randal_olson'),
#  ('JDRedding', 'EvanSinar'),
#  ('ThugMetricsNews', 'HomesAtMetacoda'),
#  ('ThugMetricsNews', 'UNDPEurasia'),
#  ('ThugMetricsNews', 'DataRobot'),
#  ('ThugMetricsNews', 'Venustucad'),
#  ('ThugMetricsNews', 'research_innova'),
#  ('ThugMetricsNews', 'irinnews'),
#  ('ThugMetricsNews', 'kaggle'),
#  ('ThugMetricsNews', 'SASsoftware'),
#  ('ThugMetricsNews', 'KirkDBorne'),
#  ('ThugMetricsNews', 'jenstirrup'),
#  ('ThugMetricsNews', 'robertoglezcano'),
#  ('acuadra', 'VizWorld'),
#  ('rasbt', 'vmirly'),
#  ('SilkDotCo', 'TechCrunch'),
#  ('SilkDotCo', 'BuzzFeed'),
#  ('JSBreet', 'albertocairo'),
#  ('p2pWebMobileIt', 'p2people'),
#  ('Sushanta__Das', 'moaimx'),
#  ('Sushanta__Das', 'GIRE_mx'),
#  ('Sushanta__Das', 'Data4mx'),
#  ('Googleulv', 'MyNarmis'),
#  ('visalyze', 'gregmancel'),
#  ('visalyze', 'EvanSinar'),
#  ('visalyze', 'DataScienceCtrl'),
#  ('visalyze', 'SR_Visual_Info'),
#  ('ChrisGorczynski', 'tableau'),
#  ('ChrisGorczynski', 'GGorczynski'),
#  ('ChartBlocks', 'flowingdata'),
#  ('ChartBlocks', 'googleanalytics'),
#  ('Privatecarfree', 'BriceDev'),
#  ('carolynewilson', 'randal_olson'),
#  ('citedeleconomie', 'SciencePresse'),
#  ('nassyemon', 'UNESCO'),
#  ('AritzSala', 'MuseumsInspire'),
#  ('AritzSala', 'Raspberry_Pi'),
#  ('AritzSala', 'computermuseum'),
#  ('narioINC', 'MuseumsInspire'),
#  ('narioINC', 'Raspberry_Pi'),
#  ('narioINC', 'computermuseum'),
#  ('ADPCareers', 'ADPCareers'),
#  ('ADPCareers', 'JenPhillipsK'),
#  ('accidental__aRt', 'randal_olson'),
#  ('k_mcdj', 'thomasforth'),
#  ('firmayati', 'NatGeo'),
#  ('firmayati', 'visualisingdata'),
#  ('firmayati', 'NadiehBremer'),
#  ('nigelhawtin', 'Demografia_CSIC'),
#  ('nigelhawtin', 'randal_olson'),
#  ('benflodge', 'MuseumsInspire'),
#  ('benflodge', 'Raspberry_Pi'),
#  ('benflodge', 'computermuseum'),
#  ('lietolem', 'MicoYuk'),
#  ('lietolem', 'analyticsonfire'),
#  ('lietolem', 'rmgoodm'),
#  ('SMyers1983', 'Sophedges'),
#  ('OsAri42', 'randal_olson'),
#  ('Roambi', 'GeologyPage'),
#  ('SilkJournalism', 'TechCrunch'),
#  ('SilkJournalism', 'SilkDotCo'),
#  ('SilkJournalism', 'BuzzFeed'),
#  ('Manuela_Stocco', 'la_stampa'),
#  ('DansLeRuSH', 'jeromebuseyne'),
#  ('strategicpolicy', '365datafr'),
#  ('strategicpolicy', 'we_do_data'),
#  ('pythoncamp', 'pycologne'),
#  ('pythoncamp', 'pythoncamp'),
#  ('pythoncamp', 'PythonSV'),
#  ('eupirates', 'rights_info'),
#  ('ashley_senn', 'EU_Eurostat'),
#  ('irregularbi', 'irregularbi'),
#  ('irregularbi', 'brian_booden'),
#  ('irregularbi', 'qlik'),
#  ('irregularbi', 'sperosck'),
#  ('sergiomajluf', 'joshsmithnyc'),
#  ('sergiomajluf', 'HollyNielsen'),
#  ('sergiomajluf', 'jsteeleeditor'),
#  ('sergiomajluf', 'EdwardTufte'),
#  ('sergiomajluf', 'blprnt'),
#  ('alfauzy', 'Ronald_vanLoon'),
#  ('damiendallimore', 'RProgLangRR'),
#  ('damiendallimore', 'thomrs7'),
#  ('damiendallimore', 'splunkdev'),
#  ('Cpikeonen', 'EU_Eurostat'),
#  ('ieli', 'seeingsideways'),
#  ('my_sidewalk', 'nytimes'),
#  ('my_sidewalk', 'dataandme'),
#  ('climasocial', 'randal_olson'),
#  ('PyLadiesATL', 'pyatl'),
#  ('DominoDataLab', 'DataIsBeautiful'),
#  ('h0neyspider', 'IITDesign'),
#  ('Geo_gournot', 'DataIsBeautiful'),
#  ('tajuddinabd', 'randal_olson'),
#  ('jeduardogonz', 'marcreguera'),
#  ('jeduardogonz', 'BlueGraniteInc'),
#  ('Cuiktlahuac', 'bryankramer'),
#  ('Simacoder', 'pycoders'),
#  ('jsberlin', 'PythonWeekly'),
#  ('research_innova', 'tableau'),
#  ('research_innova', 'jenstirrup'),
#  ('research_innova', 'DataScienceCtrl'),
#  ('research_innova', 'Venustucad'),
#  ('research_innova', 'gregmancel'),
#  ('research_innova', 'EvanSinar'),
#  ('research_innova', 'research_innova'),
#  ('research_innova', 'PostGraphics'),
#  ('research_innova', 'robertoglezcano'),
#  ('UndergrBB', 'randal_olson'),
#  ('kwhaler', 'stephen_wolfram'),
#  ('vijinh0', 'BriceDev'),
#  ('HasanIsSmrt', 'randal_olson'),
#  ('Venustucad', 'Venustucad'),
#  ('Venustucad', 'randal_olson'),
#  ('Venustucad', 'research_innova'),
#  ('Venustucad', 'jenstirrup'),
#  ('Venustucad', 'robertoglezcano'),
#  ('IsaDiependaele', 'rights_info'),
#  ('z_eisberg', 'DataIsBeautiful'),
#  ('CharlesAydin', 'kdnuggets'),
#  ('von_non_', 'randal_olson'),
#  ('askdrstats', 'polinode'),
#  ('askdrstats', 'SocioVizNet'),
#  ('askdrstats', 'randal_olson'),
#  ('askdrstats', 'AlessandroZonin'),
#  ('askdrstats', 'jheuristic'),
#  ('TimeSeriesX', 'DataIsBeautiful'),
#  ('v_vashishta', 'randal_olson'),
#  ('OSQUI_3M', 'MSImagineLatam'),
#  ('KoheiSakamoto88', 'randal_olson'),
#  ('actualham', 'daniellynds'),
#  ('actualham', 'Netlytic'),
#  ('ohnerdjoy', 'instagram'),
#  ('MicroStrategy', 'sliucool'),
#  ('MicroStrategy', 'MarkGambill2'),
#  ('SteegVan', 'bryankramer'),
#  ('DailyRpackage', 'who_ug'),
#  ('DailyRpackage', 'MinofHealthUG'),
#  ('geoconnection', 'randal_olson'),
#  ('Biff_Bruise', 'DEAGiles'),
#  ('dataratta', 'Ronald_vanLoon'),
#  ('rmgoodm', 'analyticsonfire'),
#  ('rmgoodm', 'MicoYuk'),
#  ('rmgoodm', 'rmgoodm'),
#  ('artate', 'who_ug'),
#  ('artate', 'MinofHealthUG'),
#  ('artate', 'PulseLabKampala'),
#  ('geplapper', 'Demografia_CSIC'),
#  ('geplapper', 'randal_olson'),
#  ('gregmacaltao', 'DataIsBeautiful'),
#  ('the_coW81', 'gregmancel'),
#  ('the_coW81', 'DataScienceCtrl'),
#  ('Smerity', 'CommonCrawl'),
#  ('Smerity', 'bellingcat'),
#  ('Smerity', 'Smerity'),
#  ('Smerity', 'jms_dot_py'),
#  ('vginer_upv', 'agaviriau'),
#  ('vginer_upv', 'MinSaludCol'),
#  ('OptimiseOrDie', 'charlesmeaden'),
#  ('richatmango', 'thomasforth'),
#  ('richatmango', 'robertstats'),
#  ('harrishci', 'randal_olson'),
#  ('manejandodatos', 'ContinuumIO'),
#  ('guru0509', 'randal_olson'),
#  ('AmaanC', 'randal_olson'),
#  ('vizzlo', 'DataVizAI'),
#  ('DChomprang', 'rights_info'),
#  ('AndrewBraye', 'EdwardTufte'),
#  ('Python_Quest', 'dv_geek'),
#  ('DawlaMan1', 'javacodegeeks'),
#  ('cool_python', 'py3k'),
#  ('cool_python', 'StephenPiment'),
#  ('cool_python', 'raymondh'),
#  ('cool_python', 'pythontrending'),
#  ('cool_python', 'bostonpython'),
#  ('cool_python', 'pycoders'),
#  ('pezike', 'EdwardTufte'),
#  ('Heivei', 'EU_Eurostat'),
#  ('aounsm', 'SilkDotCo'),
#  ('aounsm', 'BuzzFeed'),
#  ('DJLanyon', 'randal_olson'),
#  ('MohammadFarooq_', 'DataIsBeautiful'),
#  ('joebalalaika', 'RealPython'),
#  ('CesaredePadua', 'googletricks19'),
#  ('vikramank14', 'kdnuggets'),
#  ('vikramank14', 'Demografia_CSIC'),
#  ('vikramank14', 'rights_info'),
#  ('vikramank14', 'randal_olson'),
#  ('KathakaliSeth', 'ClimateCentral'),
#  ('_amrme', 'GeologyPage'),
#  ('t_pren', 'Roambi'),
#  ('t_pren', 'GeologyPage'),
#  ('Whyconoclast', 'randal_olson'),
#  ('mikkelkrogsholm', 'EU_Eurostat'),
#  ('mikkelkrogsholm', 'BIBrainz'),
#  ('mikkelkrogsholm', 'MicoYuk'),
#  ('Lukolyo', 'who_ug'),
#  ('Lukolyo', 'MinofHealthUG'),
#  ('Lukolyo', 'PulseLabKampala'),
#  ('juananjimenez', 'DataIsBeautiful'),
#  ('PythonDaily', 'YhatHQ'),
#  ('PythonDaily', 'bellingcat'),
#  ('PythonDaily', 'AV_PowerUp'),
#  ('PythonDaily', 'fancysandwiches'),
#  ('PythonDaily', 'CommonCrawl'),
#  ('PythonDaily', 'jydoHQ'),
#  ('PythonDaily', 'Smerity'),
#  ('PythonDaily', 'Raspberry_Pi'),
#  ('PythonDaily', 'computermuseum'),
#  ('matt_mershon', 'elevenfifty'),
#  ('hackblossom', 'djangogirlsATL'),
#  ('hackblossom', 'adriennefriend'),
#  ('RupertCook', 'EdwardTufte'),
#  ('eFe_Gil', 'WHSummit'),
#  ('eFe_Gil', 'EdwardTufte'),
#  ('eFe_Gil', 'UNDP'),
#  ('analyticsonfire', 'BIBrainz'),
#  ('analyticsonfire', 'weckerson'),
#  ('analyticsonfire', 'timoelliott'),
#  ('analyticsonfire', 'MicoYuk'),
#  ('analyticsonfire', 'rmgoodm'),
#  ('CMBInfo', 'CMBInfo'),
#  ('CMBInfo', 'infotools'),
#  ('NadiehBremer', 'NatGeo'),
#  ('NadiehBremer', 'visualisingdata'),
#  ('Aveekchatterjee', 'EhLaFrance'),
#  ('Aveekchatterjee', 'theknomos'),
#  ('homeAIinfo', 'ijanric'),
#  ('homeAIinfo', 'HansRosling'),
#  ('homeAIinfo', 'paderta'),
#  ('homeAIinfo', 'AlexCEngler'),
#  ('homeAIinfo', 'randal_olson'),
#  ('MarcucciEdoardo', 'quantifiedcode'),
#  ('SueMentors', 'evergreendata'),
#  ('StatsInTheWild', 'ToferC'),
#  ('StatsInTheWild', 'philipashlock'),
#  ('DDSecPodcast', 'randal_olson'),
#  ('ChadMurphyUMW', 'EdwardTufte'),
#  ('ChadMurphyUMW', 'samazzzz'),
#  ('ChadMurphyUMW', 'Creatuluw'),
#  ('Rbloggers', 'trebor'),
#  ('Rbloggers', 'robertstats'),
#  ('Rbloggers', 'GemmaSPearce'),
#  ('Rbloggers', 'bryankramer'),
#  ('Rbloggers', 'jposamen'),
#  ('Rbloggers', 'motioninsocial'),
#  ('Rbloggers', '365datafr'),
#  ('Rbloggers', 'CRPE_UW'),
#  ('Rbloggers', 'nytimes'),
#  ('Rbloggers', 'seanrobertgill'),
#  ('Rbloggers', 'chrisalbon'),
#  ('Rbloggers', 'MyNarmis'),
#  ('Rbloggers', 'we_do_data'),
#  ('hidroVis', 'EvanSinar'),
#  ('LoopAILabs', 'kdnuggets'),
#  ('amcrisan', 'randal_olson'),
#  ('RojasPotosi', 'who_ug'),
#  ('RojasPotosi', 'MinofHealthUG'),
#  ('RojasPotosi', 'PulseLabKampala'),
#  ('RojasPotosi', 'KirkDBorne'),
#  ('hajozaki', 'randal_olson'),
#  ('mTrabajadores', 'statsforbios'),
#  ('alex_newmayer', 'TomInHat'),
#  ('Eric_Vessier', 'Ronald_vanLoon'),
#  ('LearnRinaDay', 'IMdatafizz'),
#  ('LearnRinaDay', 'HEFCE'),
#  ('LearnRinaDay', 'randal_olson'),
#  ('EyalCarmel', 'SQLDusty'),
#  ('SrbhGaur', 'Ronald_vanLoon'),
#  ('fgmacedo', 'ThePSF'),
#  ('fgmacedo', 'ramalhoorg'),
#  ('fgmacedo', 'Coverity'),
#  ('innova_scape', 'kennelliott'),
#  ('innova_scape', 'mikescharff'),
#  ('innova_scape', 'thomasforth'),
#  ('innova_scape', 'robertstats'),
#  ('innova_scape', 'RichardACarter2'),
#  ('innova_scape', 'SASCanada'),
#  ('innova_scape', 'haddame'),
#  ('innova_scape', 'mohsin'),
#  ('innova_scape', 'nytimes'),
#  ('innova_scape', 'Manuela_Stocco'),
#  ('innova_scape', 'rav_aliahmad'),
#  ('innova_scape', 'dreich'),
#  ('innova_scape', 'MapleLeafs'),
#  ('innova_scape', 'dataandme'),
#  ('innova_scape', 'athomas74'),
#  ('innova_scape', 'Biff_Bruise'),
#  ('innova_scape', 'BdeTenley'),
#  ('innova_scape', 'SASRetail'),
#  ('innova_scape', 'WHSummit'),
#  ('innova_scape', '_jcbales'),
#  ('innova_scape', 'eagereyes'),
#  ('ggdaniel', 'raymondh'),
#  ('mikescharff', 'WHSummit'),
#  ('mikescharff', 'UNDP'),
#  ('georgeisyourman', 'knime'),
#  ('yojixyz19981', 'SonyGomes'),
#  ('mhfalaki', 'randal_olson'),
#  ('patromevo', 'adamwoodsaus'),
#  ('SalMcD', 'HollyLynnMck'),
#  ('SalMcD', 'sweetspot'),
#  ('BelgiumInvestor', 'randal_olson'),
#  ('seanrobertgill', 'jposamen'),
#  ('seanrobertgill', 'CRPE_UW'),
#  ('seanrobertgill', 'trebor'),
#  ('517design', 'Visually'),
#  ('AntoViral', 'tableau'),
#  ('AntoViral', 'paderta'),
#  ('AntoViral', 'MarkGambill2'),
#  ('AntoViral', 'DataRobot'),
#  ('AntoViral', 'randal_olson'),
#  ('AntoViral', '365datafr'),
#  ('AntoViral', 'KirkDBorne'),
#  ('AntoViral', 'rmgoodm'),
#  ('AntoViral', 'evergreendata'),
#  ('AntoViral', 'atcsapp'),
#  ('AntoViral', 'GGorczynski'),
#  ('AntoViral', 'SkytreeHQ'),
#  ('AntoViral', 'MicoYuk'),
#  ('AntoViral', 'statsforbios'),
#  ('AntoViral', 'sliucool'),
#  ('AntoViral', 'PlaceILive'),
#  ('AntoViral', 'kaggle'),
#  ('AntoViral', 'we_do_data'),
#  ('datadrivenausnz', 'Ronald_vanLoon'),
#  ('raespresso', 'CA_Careers'),
#  ('apatersonlondon', 'randal_olson'),
#  ('jtrothwell', 'gatesfoundation'),
#  ('GemmaSPearce', 'robertstats'),
#  ('GemmaSPearce', 'GemmaSPearce'),
#  ('Fernandes_Ann', 'atcsapp'),
#  ('sakistrian', 'scoopit'),
#  ('ICT_Kerion', 'randal_olson'),
#  ('rvidal', 'myvariantinfo'),
#  ('TeamMarcoAz', 'GoogleTrends'),
#  ('influx', 'raymondh'),
#  ('jclassified89', 'jclassified89'),
#  ('MarcellMontier', 'jobely'),
#  ('drmauricedawson', 'Ronald_vanLoon'),
#  ('vismtl', 'robroc'),
#  ('vismtl', 'jeanhuguesroy'),
#  ('vismtl', 'NaelShiab'),
#  ('vismtl', 'fdaudens'),
#  ('DataLensDC', 'washingtonpost'),
#  ('DataRobot', 'ianozsvald'),
#  ('DataRobot', 'gmarkall'),
#  ('DataRobot', 'PythonDaily'),
#  ('brandonh639', 'TeachTheMachine'),
#  ('brandonh639', 'alexhwoods'),
#  ('brandonh639', 'EXADude'),
#  ('lostlibrarian06', 'outsellinc'),
#  ('lostlibrarian06', 'robeirne'),
#  ('vijay_ivaturi', 'AriLamstein'),
#  ('jjstache', 'albertocairo'),
#  ('jjstache', 'flowingdata'),
#  ('nycjordi', 'UNESCO'),
#  ('jspartz', 'bayreporta'),
#  ('jspartz', 'aboutaaron'),
#  ('OpenMENA', 'ClimateDesk'),
#  ('OpenMENA', 'MaliciaRogue'),
#  ('HughHopkins', 'randal_olson'),
#  ('lmgracia', 'artwisanggeni'),
#  ('Blabladujour1', '365datafr'),
#  ('Blabladujour1', 'we_do_data'),
#  ('ricardov_cl', 'DISENO_UC'),
#  ('ricardov_cl', 'eyeofestival'),
#  ('icanwinifiwant', 'CTVMorningLive'),
#  ('icanwinifiwant', 'Keri_Adams'),
#  ('TaiebSomai', 'Creatuluw'),
#  ('vrohani', 'SciencePresse'),
#  ('srsupp', 'adamwoodsaus'),
#  ('Dicis', 'randal_olson'),
#  ('MonsieurRaccoon', 'StackDevJobs'),
#  ('MonsieurRaccoon', 'Rackspace'),
#  ('allen_aven', 'SQLJason'),
#  ('manuelgea', 'EdwardTufte'),
#  ...]

# %%
# Out:
# 2628
